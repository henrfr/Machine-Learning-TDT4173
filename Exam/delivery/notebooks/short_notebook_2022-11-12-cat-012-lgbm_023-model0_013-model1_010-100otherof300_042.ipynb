# %% [markdown]
# ## Short notebook 1
# | Name         | StudentID |
# |--------------|-----------|
# | Håkon Nese   | 506795    |
# | Henrik Friis | 506991    |
#
# Kaggle group: Team 25
#
# #### Hyperparameters
# Hyperparameters are found using Optuna. This is shown in the long notebook. This holds for all hyperparameters used.

# %%
! pip install alembic==1.8.1
! pip install anyio==3.6.1
! pip install appdirs==1.4.4
! pip install appnope==0.1.3
! pip install apturl==0.5.2
! pip install argon2-cffi==21.3.0
! pip install argon2-cffi-bindings==21.2.0
! pip install asttokens==2.0.8
! pip install async-generator==1.10
! pip install attrs==21.2.0
! pip install Automat==20.2.0
! pip install autopage==0.5.1
! pip install Babel==2.8.0
! pip install backcall==0.2.0
! pip install bcrypt==3.2.0
! pip install beautifulsoup4==4.10.0
! pip install beniget==0.4.1
! pip install bleach==5.0.1
! pip install blinker==1.4
! pip install Bottleneck==1.3.2
! pip install Brlapi==0.8.3
! pip install Brotli==1.0.9
! pip install catboost==1.1.1
! pip install category-encoders==2.5.1.post0
! pip install certifi==2020.6.20
! pip install cffi==1.15.1
! pip install chardet==4.0.0
! pip install click==8.0.3
! pip install click-plugins==1.1.1
! pip install cliff==4.0.0
! pip install cligj==0.7.2
! pip install cloud-init==22.3.4
! pip install cmaes==0.9.0
! pip install cmd2==2.4.2
! pip install colorama==0.4.4
! pip install colorlog==6.7.0
! pip install command-not-found==0.3
! pip install configobj==5.0.6
! pip install constantly==15.1.0
! pip install cryptography==3.4.8
! pip install cupshelpers==1.0
! pip install cycler==0.11.0
! pip install dbus-python==1.2.18
! pip install debugpy==1.6.3
! pip install decorator==4.4.2
! pip install defer==1.0.6
! pip install defusedxml==0.7.1
! pip install distro==1.7.0
! pip install distro-info===1.1build1
! pip install docker==5.0.3
! pip install docker-compose==1.29.2
! pip install dockerpty==0.4.1
! pip install docopt==0.6.2
! pip install duplicity==0.8.21
! pip install entrypoints==0.4
! pip install et-xmlfile==1.0.1
! pip install executing==1.0.0
! pip install fail2ban==0.11.2
! pip install fasteners==0.14.1
! pip install fastjsonschema==2.16.1
! pip install Fiona==1.8.22
! pip install fonttools==4.29.1
! pip install fs==2.4.12
! pip install future==0.18.2
! pip install gast==0.5.2
! pip install geopandas==0.12.1
! pip install gpg===1.16.0-unknown
! pip install graphviz==0.20.1
! pip install greenlet==2.0.1
! pip install h2o==3.38.0.2
! pip install html5lib==1.1
! pip install httplib2==0.20.2
! pip install hyperlink==21.0.0
! pip install idna==3.3
! pip install importlib-metadata==4.6.4
! pip install incremental==21.3.0
! pip install iniconfig==1.1.1
! pip install ipykernel==6.15.2
! pip install ipython==8.4.0
! pip install ipython-genutils==0.2.0
! pip install ipywidgets==8.0.1
! pip install jdcal==1.0
! pip install jedi==0.18.1
! pip install jeepney==0.7.1
! pip install Jinja2==3.0.3
! pip install joblib==0.17.0
! pip install json5==0.9.10
! pip install jsonpatch==1.32
! pip install jsonpointer==2.0
! pip install jsonschema==3.2.0
! pip install jupyter==1.0.0
! pip install jupyter-console==6.4.4
! pip install jupyter-core==4.11.1
! pip install jupyter-server==1.18.1
! pip install jupyter_client==7.3.5
! pip install jupyterlab==3.4.5
! pip install jupyterlab-pygments==0.2.2
! pip install jupyterlab-widgets==3.0.2
! pip install jupyterlab_server==2.15.1
! pip install keyring==23.5.0
! pip install kiwisolver==1.3.2
! pip install language-selector==0.1
! pip install launchpadlib==1.10.16
! pip install lazr.restfulclient==0.14.4
! pip install lazr.uri==1.0.6
! pip install lightgbm==3.3.3
! pip install llvmlite==0.38.0
! pip install lockfile==0.12.2
! pip install louis==3.20.0
! pip install lxml==4.8.0
! pip install lz4==3.1.3+dfsg
! pip install macaroonbakery==1.3.1
! pip install Mako==1.1.3
! pip install MarkupSafe==2.0.1
! pip install matplotlib==3.5.1
! pip install matplotlib-inline==0.1.6
! pip install mercurial==6.1.1
! pip install mistune==2.0.4
! pip install monotonic==1.6
! pip install more-itertools==8.10.0
! pip install mpmath==0.0.0
! pip install munch==2.5.0
! pip install nbclassic==0.4.3
! pip install nbclient==0.6.7
! pip install nbconvert==7.0.0
! pip install nbformat==5.4.0
! pip install nest-asyncio==1.5.5
! pip install netifaces==0.11.0
! pip install nose==1.3.7
! pip install notebook==6.4.12
! pip install notebook-shim==0.1.0
! pip install numba==0.55.1
! pip install numexpr==2.8.1
! pip install numpy==1.21.5
! pip install oauthlib==3.2.0
! pip install odfpy==1.4.2
! pip install olefile==0.46
! pip install openpyxl==3.0.9
! pip install optuna==3.0.3
! pip install packaging==21.3
! pip install pandas==1.4.1
! pip install pandocfilters==1.5.0
! pip install paramiko==2.9.3
! pip install parso==0.8.3
! pip install patsy==0.5.3
! pip install pbr==5.11.0
! pip install pexpect==4.8.0
! pip install pickleshare==0.7.5
! pip install Pillow==9.0.1
! pip install plotly==5.11.0
! pip install pluggy==0.13.0
! pip install ply==3.11
! pip install prettytable==3.5.0
! pip install prometheus-client==0.14.1
! pip install prompt-toolkit==3.0.31
! pip install protobuf==3.12.4
! pip install psutil==5.9.0
! pip install ptyprocess==0.7.0
! pip install pure-eval==0.2.2
! pip install py==1.10.0
! pip install pyasn1==0.4.8
! pip install pyasn1-modules==0.2.1
! pip install pycairo==1.20.1
! pip install pycparser==2.21
! pip install pycups==2.0.1
! pip install Pygments==2.11.2
! pip install PyGObject==3.42.1
! pip install PyHamcrest==2.0.2
! pip install pyinotify==0.9.6
! pip install PyJWT==2.3.0
! pip install pymacaroons==0.13.0
! pip install PyNaCl==1.5.0
! pip install pyOpenSSL==21.0.0
! pip install pyparsing==2.4.7
! pip install pyperclip==1.8.2
! pip install pyproj==3.4.0
! pip install pyRFC3339==1.1
! pip install pyrsistent==0.18.1
! pip install pyserial==3.5
! pip install pytest==6.2.5
! pip install python-apt==2.3.0+ubuntu2.1
! pip install python-dateutil==2.8.2
! pip install python-debian===0.1.43ubuntu1
! pip install python-dotenv==0.19.2
! pip install python-magic==0.4.24
! pip install pythran==0.10.0
! pip install pytz==2022.1
! pip install pyxdg==0.27
! pip install PyYAML==5.4.1
! pip install pyzmq==23.2.1
! pip install qtconsole==5.3.2
! pip install QtPy==2.2.0
! pip install reportlab==3.6.8
! pip install requests==2.25.1
! pip install scikit-learn==0.23.2
! pip install scipy==1.8.0
! pip install seaborn==0.11.2
! pip install SecretStorage==3.3.1
! pip install Send2Trash==1.8.0
! pip install service-identity==18.1.0
! pip install Shapely==1.8.5.post1
! pip install simplejson==3.17.6
! pip install six==1.16.0
! pip install sklearn==0.0
! pip install sniffio==1.3.0
! pip install sos==4.4
! pip install soupsieve==2.3.1
! pip install SQLAlchemy==1.4.43
! pip install ssh-import-id==5.11
! pip install stack-data==0.5.0
! pip install statsmodels==0.13.5
! pip install stevedore==4.1.0
! pip install sympy==1.9
! pip install systemd-python==234
! pip install tables==3.7.0
! pip install tabulate==0.9.0
! pip install tenacity==8.1.0
! pip install terminado==0.15.0
! pip install testpath==0.6.0
! pip install texttable==1.6.4
! pip install threadpoolctl==3.1.0
! pip install tinycss2==1.1.1
! pip install toml==0.10.2
! pip install tornado==6.2
! pip install tqdm==4.64.1
! pip install traitlets==5.3.0
! pip install trash-cli==0.17.1.14
! pip install Twisted==22.1.0
! pip install ubuntu-advantage-tools==27.11.3
! pip install ubuntu-drivers-common==0.0.0
! pip install ufoLib2==0.13.1
! pip install ufw==0.36.1
! pip install unattended-upgrades==0.1
! pip install unicodedata2==14.0.0
! pip install urllib3==1.26.5
! pip install usb-creator==0.3.7
! pip install wadllib==1.3.6
! pip install wcwidth==0.2.5
! pip install webencodings==0.5.1
! pip install websocket-client==1.2.3
! pip install widgetsnbextension==4.0.2
! pip install xdg==5
! pip install xkit==0.0.0
! pip install xlwt==1.3.0
! pip install zipp==1.0.0
! pip install zope.interface==5.4.0

# %%
import numpy as np
import pandas as pd
from shapely import wkt
import geopandas as gpd
from numba import prange, njit
from math import radians, cos, sin, asin, sqrt

# %%
busstops = pd.read_csv('busstops_norway.csv')
stores_extra = pd.read_csv('stores_extra.csv')
stores_train = pd.read_csv('stores_train.csv')
stores_test = pd.read_csv('stores_test.csv')
grunnkrets = pd.read_csv('grunnkrets_norway_stripped.csv')

busstops['geometry'] = busstops['geometry'].apply(wkt.loads)
gdf = gpd.GeoDataFrame(busstops, crs='EPSG:4326')

# %%
grunnkrets = grunnkrets.sort_values(by=["grunnkrets_id", "year"]).drop_duplicates(subset=["grunnkrets_id"], keep='last')

# %%
# For calculating the distance in Kilometres   
@njit
def geo_distance(La1, Lo1, La2, Lo2):  
       
    # The math module contains the function name "radians" which is used for converting the degrees value into radians.  
    Lo1 = radians(Lo1)  
    Lo2 = radians(Lo2)  
    La1 = radians(La1)  
    La2 = radians(La2)  
        
    # Using the "Haversine formula"  
    D_Lo = Lo2 - Lo1  
    D_La = La2 - La1  
    P = sin(D_La / 2)**2 + cos(La1) * cos(La2) * sin(D_Lo / 2)**2  
   
    Q = 2 * asin(sqrt(P))  
      
    # The radius of earth in kilometres.  
    R_km = 6371  
        
    # calculate result in meters
    return(Q * R_km)  * 1000

# %%
@njit('i4[:](f8[:,:], f8[:,:], i8, b1)', parallel=True)
def number_of_points_closer_than_numba(x, y, distance_meters: int = 1000, x_and_y_same_array=False):
    z = np.empty(x.shape[0], dtype=np.int32)
    num_rows = x.shape[0]
    for i in prange(num_rows):
        # number of points closer that distance_meters from point
        count = np.count_nonzero(np.array([geo_distance(x[i][0], x[i][1], y[j][0], y[j][1]) < distance_meters 
            for j in prange(y.shape[0])]))
        # remove 1 if x and y are equal as distance to self is 0
        if x_and_y_same_array:
            count -= 1
        z[i] = count
    return z

# %%
@njit('Tuple((i4[:], f8[:]))(f8[:,:], f8[:,:], b1)', parallel=True)
def closest_points_numba(x, y, x_and_y_same_array=True):
    closest_points_distance = np.empty(x.shape[0], dtype=np.float64)
    closest_points_index = np.empty(x.shape[0], dtype=np.int32)

    for i in prange(x.shape[0]):
        # closest point that is not itself
        distance_points = np.array([geo_distance(x[i][0], x[i][1], y[j][0], y[j][1]) if x_and_y_same_array == False or x[i][0] != y[j][0] and x[i][1] != y[j][1] else np.inf
                                    for j in range(y.shape[0])])
        closest_point_index = np.argmin(distance_points)
        closest_point_distance = np.min(distance_points)
        closest_points_distance[i] = closest_point_distance
        closest_points_index[i] = closest_point_index

    return closest_points_index, closest_points_distance

# %%
def append_number_of_points_closer_than(df, points_in_df, geo_points, column_name, distance_meters: int = 1000, x_and_y_same_array=False):
    close_elements = number_of_points_closer_than_numba(x=points_in_df, y=geo_points, distance_meters=distance_meters, x_and_y_same_array=x_and_y_same_array)
    df[column_name] = close_elements

# %%
def append_closest_points(df, geo_df, points_in_df, geo_points, index_column_name, new_column_name, x_and_y_same_array=False):
    closest_elements_index, closest_elements_distance = closest_points_numba(points_in_df, geo_points, x_and_y_same_array=x_and_y_same_array)
    df[new_column_name] = closest_elements_distance
    # add id of point that was closest to each point in df 
    print(closest_elements_distance, closest_elements_index)
    df[index_column_name] = geo_df.iloc[closest_elements_index].set_index(df.index)[index_column_name]

# %%
# Creating a np array of [lat, lon] from shapely GeoPoints
geo_busstops = np.array(list([geo.y, geo.x] for geo in gdf.geometry.to_numpy()))

# %%
append_number_of_points_closer_than(gdf, geo_busstops, geo_busstops, "num_of_buss_stops_closer_that_1000_to_busstop", x_and_y_same_array=True)
gdf.to_csv("busstops_norway_with_count.csv")

# %%
# concat all data of stores together, adding index with train name from where the row came from
stores = pd.concat({"train": stores_train, "extra": stores_extra, "test": stores_test})

# %%
# all the lat lons of the stores, to a numpy array so that the numba-function can compute the distances
geo_stores = stores[["lat", "lon"]].to_numpy()

# %%
# append number of close stores and close busstops
append_number_of_points_closer_than(stores, geo_stores, geo_stores, "other_stores_1000", x_and_y_same_array=True, distance_meters=1000)
append_number_of_points_closer_than(stores, geo_stores, geo_stores, "other_stores_100", x_and_y_same_array=True, distance_meters=100)
append_number_of_points_closer_than(stores, geo_stores, geo_stores, "other_stores_50", x_and_y_same_array=True, distance_meters=50)
append_number_of_points_closer_than(stores, geo_stores, geo_stores, "other_stores_250", x_and_y_same_array=True, distance_meters=250)
append_number_of_points_closer_than(stores, geo_stores, geo_busstops, "buss_stops_1000", x_and_y_same_array=False, distance_meters=1000)
append_number_of_points_closer_than(stores, geo_stores, geo_busstops, "buss_stops_300", x_and_y_same_array=False, distance_meters=300)

# %%
append_closest_points(
    df=stores, 
    geo_df=busstops, 
    points_in_df=geo_stores, 
    geo_points=geo_busstops, 
    index_column_name='busstop_id', 
    new_column_name="distance_closest_busstop", 
    x_and_y_same_array=False)
# Out:
# [495.65295876 102.35551582  25.53176743 ... 114.20099103  63.82726397
#  125.76760068] [48753   140 58056 ... 30708  9534 56169]

# %%
# find all stores that has a grunnkrets_id that doesn't exist in the grunnkrets table
stores_wo_grunnkrets = stores.merge(grunnkrets[['grunnkrets_id', 'grunnkrets_name']], how="left", on="grunnkrets_id")
nan_stores_all = stores_wo_grunnkrets.loc[stores_wo_grunnkrets['grunnkrets_name'].isna()]
outer_stores_test = stores_test.merge(grunnkrets[['grunnkrets_id', 'grunnkrets_name']], how="left", on="grunnkrets_id")
nan_stores = outer_stores_test.loc[outer_stores_test['grunnkrets_name'].isna()]

# %%
# copy grunnkrets of stores so that we can impute the grunnkrets_id of the test_stores that has a bad grunnkrets_id
stores['grunnkrets_1'] = stores['grunnkrets_id']
append_closest_points(
    df=nan_stores,
    geo_df=stores[~stores.grunnkrets_id.isin(nan_stores_all.grunnkrets_id)],
    points_in_df=nan_stores[["lat", "lon"]].to_numpy(),
    geo_points=geo_stores,
    index_column_name='grunnkrets_1',
    new_column_name='closest_store_id',
    x_and_y_same_array=True
)
# Out:
# [8.33037557e+02 1.13153469e+02 8.71270649e-01 9.92971322e+03
#  6.35282105e+03 2.77653490e+04 1.59262209e+03 1.51000246e+04
#  6.76384356e+03 2.38863345e+02 2.93062827e+03 1.56463351e+03
#  6.54021281e+03 2.73123562e+04 4.19203250e+02 2.04058526e+04
#  2.35162647e+04 2.46535005e+03 1.41086385e+03 1.13350247e+04
#  1.76739494e+03 4.45915791e+03 1.26082022e+04 3.61803004e+03
#  1.68662920e+03 8.14563288e+03 2.93062827e+03] [47589 16979 14155  1596  7099 46512 49150 14062 28820  7907 49856 14595
#  16959 10586  1375 11272  2199 14393 14714  9886 13520 25574 46335   659
#  42344 14702 44173]
# /tmp/ipykernel_1832961/1070740115.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_column_name] = closest_elements_distance
# /tmp/ipykernel_1832961/1070740115.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[index_column_name] = geo_df.iloc[closest_elements_index].set_index(df.index)[index_column_name]

# %%
# rename column of the grunnkrets_id of the stores with bad grunnkrets_id
nan_stores.grunnkrets_id = nan_stores.grunnkrets_1
# Out:
# /tmp/ipykernel_1832961/1378478374.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nan_stores.grunnkrets_id = nan_stores.grunnkrets_1

# %%
# set grunnkrets_id to grunnkrets_id of the closest store, that is a good grunnkrets_id
for _, row in nan_stores[['store_id', 'grunnkrets_1']].iterrows():
    stores.loc[stores.store_id == row['store_id'], 'grunnkrets_id'] = row.grunnkrets_1

# %%
stores.drop(columns="grunnkrets_1")
stores.to_csv("stores.csv")

# %%
stores = pd.read_csv("stores.csv")
busstops = pd.read_csv("busstops_norway_with_count.csv")
age_dist = pd.read_csv("grunnkrets_age_distribution.csv")
households = pd.read_csv("grunnkrets_households_num_persons.csv")
income = pd.read_csv("grunnkrets_income_households.csv")
grunnkrets = pd.read_csv("grunnkrets_norway_stripped.csv")
plaace = pd.read_csv("plaace_hierarchy.csv")

# %%
grunnkrets.drop(columns=['grunnkrets_name', 'geometry'], inplace=True)

# %%
grunnkrets = grunnkrets.sort_values(by=["grunnkrets_id", "year"]).drop_duplicates(subset=["grunnkrets_id"], keep='last')

# %%
# remove 2015 data and year column
households = households.sort_values(by=["grunnkrets_id", "year"]).drop_duplicates(subset=["grunnkrets_id"], keep='last')
income = income.sort_values(by=["grunnkrets_id", "year"]).drop_duplicates(subset=["grunnkrets_id"], keep='last')
age_dist = age_dist.sort_values(by=["grunnkrets_id", "year"]).drop_duplicates(subset=["grunnkrets_id"], keep='last')
grunnkrets.drop(columns='year', inplace=True)
households.drop(columns='year', inplace=True)
income.drop(columns='year', inplace=True)
age_dist.drop(columns='year', inplace=True)

# %%
# set index to grunnkrets_id for merging
households.set_index('grunnkrets_id', inplace=True)
grunnkrets.set_index('grunnkrets_id', inplace=True)
income.set_index('grunnkrets_id', inplace=True)
age_dist.set_index('grunnkrets_id', inplace=True)

# %%
busstops.drop(columns=['geometry', 'Unnamed: 0'], inplace=True)

# %%
stores = stores.rename(columns={"Unnamed: 0": "dataset", "Unnamed: 1": "range_index"}).set_index(["dataset", "range_index"])
stores.drop(columns='sales_channel_name', inplace=True)
stores['copy_index'] = stores.index

# %%
all_merged = stores.merge(grunnkrets, left_on='grunnkrets_id', right_index=True) \
                   .merge(households, left_on='grunnkrets_id', right_index=True, how="left") \
                   .merge(income, left_on='grunnkrets_id', right_index=True, how="left") \
                   .merge(age_dist, left_on='grunnkrets_id', right_index=True, how="left") \
                   .merge(plaace, on='plaace_hierarchy_id') \
                   .merge(busstops, on='busstop_id')

# %%
all_merged.index = pd.MultiIndex.from_tuples(
    all_merged['copy_index'], 
    names=['dataset', 'range_index'])

all_merged.drop(columns=['copy_index', 'year', 'plaace_hierarchy_id', 'sales_channel_name', 'lv1_desc', 'lv2_desc', 'lv3_desc', 'lv4_desc'], inplace=True)

# %%
all_merged.to_csv("all_merged.csv")

# %%
grunnkrets = pd.read_csv('grunnkrets_norway_stripped.csv')
grunnkrets_ages = pd.read_csv('grunnkrets_age_distribution.csv')
grunnkrets_household = pd.read_csv("grunnkrets_households_num_persons.csv")
grunnkrets_household = grunnkrets_household.sort_values(by=["grunnkrets_id", "year"]).drop_duplicates(subset=["grunnkrets_id"], keep='last')
grunnkrets_ages = grunnkrets_ages.sort_values(by=["grunnkrets_id", "year"]).drop_duplicates(subset=["grunnkrets_id"], keep='last')
grunnkrets = grunnkrets.sort_values(by=["grunnkrets_id", "year"]).drop_duplicates(subset=["grunnkrets_id"], keep='last')

# %%
grunnkrets_household.drop(columns="year", inplace=True)
grunnkrets_household["sum_people"] = grunnkrets_household.drop(columns="grunnkrets_id").sum(axis=1)

# %%
df = grunnkrets_ages.drop_duplicates(subset=["grunnkrets_id"], keep='last')
df = grunnkrets.merge(df, how='left', on='grunnkrets_id')
df["grunnkrets_population"] = df.drop(columns=["grunnkrets_id", "year_x", "year_y", "area_km2", "geometry", "municipality_name", "district_name", "grunnkrets_name"]).sum(axis=1)
df = df.merge(grunnkrets_household[['grunnkrets_id', "sum_people"]], how="left", on="grunnkrets_id")
df['grunnkrets_population'] = df.apply(
    lambda row: row['sum_people'] if row['grunnkrets_population'] == 0 else row['grunnkrets_population'],
    axis=1
)
df["district_population"] = df.groupby("district_name")["grunnkrets_population"].transform("sum")
df["municipality_population"] = df.groupby("municipality_name")["grunnkrets_population"].transform("sum")
df["district_area"] = df.groupby("district_name")["area_km2"].transform("sum")
df["municipality_area"] = df.groupby("municipality_name")["area_km2"].transform("sum")
ages = [0,3,7,13,18,25,31,41,54,65,78,91]
# ages = [0,5,12,18,30,45,65,91]
ages = [0,15,35,65,91]
# ages = list(range(92))
for j in range(1, len(ages)):  
    age_from = ages[j-1]
    age_to = ages[j]
    df[f"grunnkrets_age_{age_from}-{age_to-1}"] = df[df.columns[df.columns.isin([f"age_{i}" for i in range(age_from, age_to)])]].sum(axis=1)
    df[f"grunnkrets_age_{age_from}-{age_to-1}_distribution"] = df[f"grunnkrets_age_{age_from}-{age_to-1}"]/df["grunnkrets_population"]

for name in ["district_name", "municipality_name"]:
    for j, age in enumerate(ages):
        prefix = name.split("_")[0]
        if j == 0:
            pass
        else:
            columns = [f"age_{i}" for i in range(ages[j-1], age)]
            columns.append(name)
            df[f"{prefix}_age_{ages[j-1]}-{ages[j]-1}"] = df[df.columns[df.columns.isin(columns)]].groupby(name).transform("sum").sum(axis=1)
            df[f"{prefix}_age_{ages[j-1]}-{ages[j]-1}_distribution"] = df[f"{prefix}_age_{ages[j-1]}-{ages[j]-1}"]/df[f"{prefix}_population"]
df["grunnkrets_density"] = df.grunnkrets_population/df.area_km2
df["district_density"] = df.district_population/df.district_area
df["municipality_density"] = df.municipality_population/df.municipality_area

df = df.drop(columns=[f"age_{i}" for i in range(91)])
df = df.drop(columns=["year_y"])
df = df.rename(columns={"year_x": "year"})

# %%
df.to_csv("grunnkrets_norway_large.csv", index=False)

# %%
all_data = pd.read_csv("all_merged.csv")
all_data_large = pd.read_csv("grunnkrets_norway_large.csv")

ages = [0,15, 35,65,91]

cols = []
for name in ["district_age", "municipality_age"]:
    for j in range(1, len(ages)):  
        age_from = ages[j-1]
        age_to = ages[j]
        col_name = f"{name}_{age_from}-{age_to-1}"
        col_name = col_name + "_distribution"
        cols.append(col_name)
        col_mean, col_std = all_data_large[col_name].mean(), all_data_large[col_name].std()
cols.extend(['grunnkrets_id', 
        'grunnkrets_population',
        'district_population', 
        'municipality_population', 
        'district_area', 
        'municipality_area', 
        'municipality_density', 
        'district_density', 
])
all_data_large = all_data_large[cols]
all_data.set_index(["dataset", "range_index"], inplace=True)
all_data['copy_index'] = all_data.index
all_data = all_data.merge(all_data_large, how="left", on='grunnkrets_id')
all_data.index = pd.MultiIndex.from_tuples(
    all_data['copy_index'], 
    names=['dataset', 'range_index'])
all_data.drop(columns=['age_'+str(i) for i in range(91)], inplace=True)

# %%
all_data = all_data.groupby(["lv1", "district_name"]) \
    .apply(lambda gdf: 
        gdf.assign(
            lv1_population_district_div_count_stores=lambda gdf:  gdf["district_population"].mean() / gdf["store_id"].count() 
        )
    ).droplevel(0)

all_data.index = pd.MultiIndex.from_tuples(
    all_data['copy_index'], 
    names=['dataset', 'range_index'])

all_data = all_data.groupby(["lv2", "district_name"]) \
    .apply(lambda gdf: 
        gdf.assign(
            lv2_population_district_div_count_stores=lambda gdf:  gdf["district_population"].mean() / gdf["store_id"].count() 
        )
    ).droplevel(0)

all_data.index = pd.MultiIndex.from_tuples(
    all_data['copy_index'], 
    names=['dataset', 'range_index'])


all_data = all_data.groupby(["lv3", "district_name"]) \
    .apply(lambda gdf: 
        gdf.assign(
            lv3_population_district_div_count_stores=lambda gdf:  gdf["district_population"].mean() / gdf["store_id"].count() 
        )
    ).droplevel(0)

all_data.index = pd.MultiIndex.from_tuples(
    all_data['copy_index'], 
    names=['dataset', 'range_index'])

all_data = all_data.groupby(["lv4", "district_name"]) \
    .apply(lambda gdf: 
        gdf.assign(
            lv4_population_district_div_count_stores=lambda gdf:  gdf["district_population"].mean() / gdf["store_id"].count() 
        )
    ).droplevel(0)

all_data.index = pd.MultiIndex.from_tuples(
    all_data['copy_index'], 
    names=['dataset', 'range_index'])

all_data = all_data.groupby(["lv1", "municipality_name"]) \
    .apply(lambda gdf: 
        gdf.assign(
            lv1_population_municipality_div_count_stores=lambda gdf:  gdf["municipality_population"].mean() / gdf["store_id"].count() 
        )
    ).droplevel(0)

all_data.index = pd.MultiIndex.from_tuples(
    all_data['copy_index'], 
    names=['dataset', 'range_index'])

all_data = all_data.groupby(["lv2", "municipality_name"]) \
    .apply(lambda gdf: 
        gdf.assign(
            lv2_population_municipality_div_count_stores=lambda gdf:  gdf["municipality_population"].mean() / gdf["store_id"].count() 
        )
    ).droplevel(0)

all_data.index = pd.MultiIndex.from_tuples(
    all_data['copy_index'], 
    names=['dataset', 'range_index'])

all_data = all_data.groupby(["lv3", "municipality_name"]) \
    .apply(lambda gdf: 
        gdf.assign(
            lv3_population_municipality_div_count_stores=lambda gdf:  gdf["municipality_population"].mean() / gdf["store_id"].count() 
        )
    ).droplevel(0)

all_data.index = pd.MultiIndex.from_tuples(
    all_data['copy_index'], 
    names=['dataset', 'range_index'])

all_data = all_data.groupby(["lv4", "municipality_name"]) \
    .apply(lambda gdf: 
        gdf.assign(
            lv4_population_municipality_div_count_stores=lambda gdf:  gdf["municipality_population"].mean() / gdf["store_id"].count() 
        )
    ).droplevel(0)

all_data.index = pd.MultiIndex.from_tuples(
    all_data['copy_index'], 
    names=['dataset', 'range_index'])

all_data.drop(columns='copy_index', inplace=True)

# %%
all_data.to_csv("all_with_stores_pop.csv")

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import  StackingRegressor
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, RobustScaler
from catboost import CatBoostRegressor
import lightgbm as lgb

# %%
def export_to_kaggle_submission(test_df: pd.DataFrame, y_pred_scaled: pd.Series, filename: str):
    y_pred = np.expm1(y_pred_scaled)
    y_pred[y_pred < 0] = 0

    test_df['predicted'] = y_pred
    test_df.index.names = ['id']
    test_df['predicted'].to_csv(f"{filename}.csv")

# %%
all_data = pd.read_csv("all_with_stores_pop.csv")
all_data.set_index(["dataset", "range_index"], inplace=True)
all_data['in_mall'] = all_data['mall_name'].notna()
all_data['in_chain'] = all_data['chain_name'].notna()
all_data['mall_name'] = all_data['mall_name'].fillna("None")
all_data['as'] = all_data['store_name'].str.contains(r"\b(AS)\b", case=False, regex=True)
all_data['chain_name'] = all_data['chain_name'].fillna("None")
all_data['busstop_id'] = all_data['busstop_id'].map(str)
all_data['lv1'] = all_data['lv1'].map(str)
all_data['lv2'] = all_data['lv2'].map(str)
all_data['lv3'] = all_data['lv3'].map(str)
all_data['lv4'] = all_data['lv4'].map(str)
all_data.drop(columns=[
    'store_name',
    'address',
    'importance_level',
    'busstop_id', 
    'other_stores_50', 
    'buss_stops_300', 
    'municipality_name', 
    'lv1', 
    'lat', 
    'couple_children_6_to_17_years', 
    'couple_without_children_x', 
    'single_parent_children_0_to_5_years', 
    'singles_x', 
    'singles_y', 
    'couple_without_children_y', 
    'couple_with_children', 
    'district_age_0-14_distribution', 
    'district_age_65-90_distribution', 
    'grunnkrets_population', 
    'municipality_density', 
    'all_households', 
    'lv2_population_district_div_count_stores', 
    'lv1_population_municipality_div_count_stores', 
    'lv2_population_municipality_div_count_stores', 
    'in_mall', 
    'lv3_population_district_div_count_stores', 
    'district_name', 
    'num_of_buss_stops_closer_that_1000_to_busstop', 
    'municipality_age_0-14_distribution', 
    'municipality_age_35-64_distribution', 
    'municipality_age_65-90_distribution', 
    ], inplace=True)

data_with_label = all_data.loc[["train"]]

data_with_label.set_index('store_id', inplace=True)
data_without_label = all_data.loc[['test']]
data_without_label.set_index('store_id', inplace=True)
data_without_label.drop(columns=["revenue"], inplace=True)

X, y = data_with_label.loc[:, data_with_label.columns != 'revenue'], data_with_label['revenue']
y_scaled = np.log1p(y)


X_train = X
y_train = y
y_train_scaled = y_scaled
X_test = data_without_label
# Out:
# /tmp/ipykernel_1832961/639205308.py:6: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   all_data['as'] = all_data['store_name'].str.contains(r"\b(AS)\b", case=False, regex=True)

# %%
numeric_features = X_train.select_dtypes(include=[np.number]).columns
numeric_features = list(numeric_features.to_numpy())

numeric_transformer = Pipeline(
    steps=[
        ("imputer", SimpleImputer(strategy="median")),
        ("scaler", RobustScaler())]
)

categorical_features = X_train.select_dtypes(include=[np.object0]).columns
categorical_transformer = Pipeline(
    steps=[
        ("imputer", SimpleImputer(fill_value="missing", strategy="constant")),
        ("onehotencoding", OneHotEncoder(handle_unknown="ignore"))
    ]
)


preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numeric_features),
        ("cat", categorical_transformer, categorical_features),
    ],
    remainder="passthrough",
)

categorical_features_include_bool = list(categorical_features.to_numpy())
categorical_features_include_bool.extend(list(X.select_dtypes(include=[np.bool8]).columns.to_numpy()))

# %%
param = {'loss_function': 'Huber:delta=0.5', 'colsample_bylevel': 0.012326837446695698, 'depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', "eval_metric": "RMSE", 'n_estimators': 2826}
cat = Pipeline(steps=[('preprocessor', preprocessor), ('cat', CatBoostRegressor(**param))])
cat.fit(X_train,
        y_train_scaled,
        )
y_cat = cat.predict(X_test)
export_to_kaggle_submission(X_test, y_cat, "2022-11-11-catboost-last")
# Out:
# 0:	learn: 1.8173687	total: 11.1ms	remaining: 31.3s
# 1:	learn: 1.7555627	total: 24.1ms	remaining: 34.1s
# 2:	learn: 1.7049039	total: 35.1ms	remaining: 33s
# 3:	learn: 1.6605540	total: 45.6ms	remaining: 32.2s
# 4:	learn: 1.6219274	total: 56ms	remaining: 31.6s
# 5:	learn: 1.5867033	total: 68.4ms	remaining: 32.2s
# 6:	learn: 1.5553510	total: 79.1ms	remaining: 31.8s
# 7:	learn: 1.5265496	total: 89.6ms	remaining: 31.6s
# 8:	learn: 1.5001491	total: 100ms	remaining: 31.3s
# 9:	learn: 1.4753295	total: 111ms	remaining: 31.3s
# 10:	learn: 1.4500861	total: 122ms	remaining: 31.1s
# 11:	learn: 1.4281178	total: 127ms	remaining: 29.8s
# 12:	learn: 1.4009763	total: 138ms	remaining: 29.8s
# 13:	learn: 1.3814610	total: 149ms	remaining: 29.9s
# 14:	learn: 1.3488538	total: 159ms	remaining: 29.8s
# 15:	learn: 1.3103220	total: 170ms	remaining: 29.8s
# 16:	learn: 1.2586481	total: 181ms	remaining: 29.9s
# 17:	learn: 1.2438227	total: 192ms	remaining: 29.9s
# 18:	learn: 1.2291037	total: 202ms	remaining: 29.9s
# 19:	learn: 1.1938722	total: 213ms	remaining: 29.9s
# 20:	learn: 1.1729431	total: 225ms	remaining: 30s
# 21:	learn: 1.1611881	total: 235ms	remaining: 30s
# 22:	learn: 1.1475065	total: 247ms	remaining: 30s
# 23:	learn: 1.1344045	total: 257ms	remaining: 30s
# 24:	learn: 1.1243139	total: 267ms	remaining: 30s
# 25:	learn: 1.0969005	total: 279ms	remaining: 30s
# 26:	learn: 1.0872393	total: 289ms	remaining: 30s
# 27:	learn: 1.0786427	total: 300ms	remaining: 30s
# 28:	learn: 1.0617675	total: 310ms	remaining: 29.9s
# 29:	learn: 1.0526093	total: 321ms	remaining: 29.9s
# 30:	learn: 1.0450473	total: 331ms	remaining: 29.9s
# 31:	learn: 1.0380204	total: 342ms	remaining: 29.8s
# 32:	learn: 1.0216343	total: 352ms	remaining: 29.8s
# 33:	learn: 1.0114263	total: 364ms	remaining: 29.9s
# 34:	learn: 1.0044828	total: 375ms	remaining: 29.9s
# 35:	learn: 0.9983834	total: 385ms	remaining: 29.9s
# 36:	learn: 0.9932279	total: 396ms	remaining: 29.9s
# 37:	learn: 0.9817789	total: 407ms	remaining: 29.8s
# 38:	learn: 0.9757516	total: 419ms	remaining: 29.9s
# 39:	learn: 0.9669020	total: 430ms	remaining: 29.9s
# 40:	learn: 0.9609034	total: 441ms	remaining: 29.9s
# 41:	learn: 0.9566053	total: 452ms	remaining: 29.9s
# 42:	learn: 0.9520960	total: 462ms	remaining: 29.9s
# 43:	learn: 0.9481134	total: 473ms	remaining: 29.9s
# 44:	learn: 0.9438982	total: 484ms	remaining: 29.9s
# 45:	learn: 0.9384511	total: 495ms	remaining: 29.9s
# 46:	learn: 0.9356621	total: 506ms	remaining: 29.9s
# 47:	learn: 0.9329196	total: 516ms	remaining: 29.9s
# 48:	learn: 0.9256269	total: 527ms	remaining: 29.9s
# 49:	learn: 0.9081313	total: 538ms	remaining: 29.8s
# 50:	learn: 0.9030180	total: 549ms	remaining: 29.9s
# 51:	learn: 0.8989569	total: 559ms	remaining: 29.8s
# 52:	learn: 0.8958592	total: 570ms	remaining: 29.8s
# 53:	learn: 0.8918803	total: 581ms	remaining: 29.8s
# 54:	learn: 0.8899203	total: 583ms	remaining: 29.4s
# 55:	learn: 0.8873965	total: 596ms	remaining: 29.5s
# 56:	learn: 0.8828239	total: 607ms	remaining: 29.5s
# 57:	learn: 0.8807728	total: 618ms	remaining: 29.5s
# 58:	learn: 0.8789720	total: 620ms	remaining: 29.1s
# 59:	learn: 0.8770770	total: 631ms	remaining: 29.1s
# 60:	learn: 0.8724448	total: 642ms	remaining: 29.1s
# 61:	learn: 0.8676380	total: 654ms	remaining: 29.1s
# 62:	learn: 0.8662365	total: 664ms	remaining: 29.1s
# 63:	learn: 0.8644286	total: 677ms	remaining: 29.2s
# 64:	learn: 0.8597782	total: 688ms	remaining: 29.2s
# 65:	learn: 0.8578571	total: 699ms	remaining: 29.2s
# 66:	learn: 0.8542332	total: 710ms	remaining: 29.2s
# 67:	learn: 0.8529644	total: 720ms	remaining: 29.2s
# 68:	learn: 0.8503185	total: 724ms	remaining: 28.9s
# 69:	learn: 0.8489099	total: 735ms	remaining: 28.9s
# 70:	learn: 0.8459209	total: 746ms	remaining: 28.9s
# 71:	learn: 0.8440547	total: 756ms	remaining: 28.9s
# 72:	learn: 0.8425591	total: 767ms	remaining: 28.9s
# 73:	learn: 0.8396092	total: 777ms	remaining: 28.9s
# 74:	learn: 0.8374080	total: 788ms	remaining: 28.9s
# 75:	learn: 0.8364046	total: 798ms	remaining: 28.9s
# 76:	learn: 0.8339071	total: 809ms	remaining: 28.9s
# 77:	learn: 0.8332175	total: 820ms	remaining: 28.9s
# 78:	learn: 0.8262123	total: 831ms	remaining: 28.9s
# 79:	learn: 0.8241024	total: 842ms	remaining: 28.9s
# 80:	learn: 0.8171795	total: 853ms	remaining: 28.9s
# 81:	learn: 0.8160931	total: 864ms	remaining: 28.9s
# 82:	learn: 0.8154368	total: 875ms	remaining: 28.9s
# 83:	learn: 0.8137709	total: 885ms	remaining: 28.9s
# 84:	learn: 0.8090607	total: 896ms	remaining: 28.9s
# 85:	learn: 0.8080888	total: 900ms	remaining: 28.7s
# 86:	learn: 0.8064168	total: 911ms	remaining: 28.7s
# 87:	learn: 0.8055058	total: 921ms	remaining: 28.7s
# 88:	learn: 0.8049692	total: 932ms	remaining: 28.7s
# 89:	learn: 0.8034536	total: 942ms	remaining: 28.6s
# 90:	learn: 0.8026385	total: 953ms	remaining: 28.6s
# 91:	learn: 0.8009893	total: 964ms	remaining: 28.6s
# 92:	learn: 0.8006069	total: 966ms	remaining: 28.4s
# 93:	learn: 0.7988658	total: 976ms	remaining: 28.4s
# 94:	learn: 0.7978280	total: 987ms	remaining: 28.4s
# 95:	learn: 0.7971570	total: 998ms	remaining: 28.4s
# 96:	learn: 0.7963373	total: 1.01s	remaining: 28.4s
# 97:	learn: 0.7956212	total: 1.02s	remaining: 28.4s
# 98:	learn: 0.7948397	total: 1.03s	remaining: 28.4s
# 99:	learn: 0.7936719	total: 1.04s	remaining: 28.4s
# 100:	learn: 0.7930066	total: 1.05s	remaining: 28.4s
# 101:	learn: 0.7914278	total: 1.06s	remaining: 28.4s
# 102:	learn: 0.7906560	total: 1.07s	remaining: 28.4s
# 103:	learn: 0.7901255	total: 1.08s	remaining: 28.4s
# 104:	learn: 0.7891027	total: 1.09s	remaining: 28.2s
# 105:	learn: 0.7867396	total: 1.1s	remaining: 28.2s
# 106:	learn: 0.7858514	total: 1.11s	remaining: 28.2s
# 107:	learn: 0.7855427	total: 1.12s	remaining: 28.2s
# 108:	learn: 0.7850690	total: 1.13s	remaining: 28.2s
# 109:	learn: 0.7839535	total: 1.14s	remaining: 28.2s
# 110:	learn: 0.7826719	total: 1.15s	remaining: 28.2s
# 111:	learn: 0.7822114	total: 1.16s	remaining: 28.2s
# 112:	learn: 0.7817557	total: 1.17s	remaining: 28.2s
# 113:	learn: 0.7813408	total: 1.18s	remaining: 28.2s
# 114:	learn: 0.7801481	total: 1.19s	remaining: 28.2s
# 115:	learn: 0.7795755	total: 1.21s	remaining: 28.2s
# 116:	learn: 0.7789448	total: 1.22s	remaining: 28.2s
# 117:	learn: 0.7784672	total: 1.23s	remaining: 28.3s
# 118:	learn: 0.7767456	total: 1.25s	remaining: 28.4s
# 119:	learn: 0.7761645	total: 1.26s	remaining: 28.4s
# 120:	learn: 0.7751012	total: 1.27s	remaining: 28.4s
# 121:	learn: 0.7743464	total: 1.28s	remaining: 28.4s
# 122:	learn: 0.7730362	total: 1.29s	remaining: 28.4s
# 123:	learn: 0.7720460	total: 1.3s	remaining: 28.4s
# 124:	learn: 0.7716641	total: 1.31s	remaining: 28.4s
# 125:	learn: 0.7712592	total: 1.32s	remaining: 28.4s
# 126:	learn: 0.7707086	total: 1.33s	remaining: 28.4s
# 127:	learn: 0.7698042	total: 1.34s	remaining: 28.4s
# 128:	learn: 0.7689648	total: 1.35s	remaining: 28.3s
# 129:	learn: 0.7685887	total: 1.37s	remaining: 28.3s
# 130:	learn: 0.7680424	total: 1.38s	remaining: 28.3s
# 131:	learn: 0.7675322	total: 1.39s	remaining: 28.3s
# 132:	learn: 0.7666572	total: 1.4s	remaining: 28.3s
# 133:	learn: 0.7664003	total: 1.41s	remaining: 28.3s
# 134:	learn: 0.7658334	total: 1.42s	remaining: 28.3s
# 135:	learn: 0.7654656	total: 1.43s	remaining: 28.3s
# 136:	learn: 0.7652814	total: 1.44s	remaining: 28.3s
# 137:	learn: 0.7649263	total: 1.45s	remaining: 28.3s
# 138:	learn: 0.7645208	total: 1.46s	remaining: 28.3s
# 139:	learn: 0.7639332	total: 1.47s	remaining: 28.3s
# 140:	learn: 0.7636315	total: 1.49s	remaining: 28.3s
# 141:	learn: 0.7627262	total: 1.5s	remaining: 28.3s
# 142:	learn: 0.7619169	total: 1.5s	remaining: 28.3s
# 143:	learn: 0.7617803	total: 1.52s	remaining: 28.3s
# 144:	learn: 0.7615235	total: 1.53s	remaining: 28.2s
# 145:	learn: 0.7611742	total: 1.54s	remaining: 28.2s
# 146:	learn: 0.7605272	total: 1.55s	remaining: 28.2s
# 147:	learn: 0.7603006	total: 1.56s	remaining: 28.2s
# 148:	learn: 0.7598625	total: 1.57s	remaining: 28.2s
# 149:	learn: 0.7590366	total: 1.58s	remaining: 28.2s
# 150:	learn: 0.7580213	total: 1.59s	remaining: 28.2s
# 151:	learn: 0.7577374	total: 1.6s	remaining: 28.2s
# 152:	learn: 0.7569442	total: 1.61s	remaining: 28.2s
# 153:	learn: 0.7567387	total: 1.61s	remaining: 28s
# 154:	learn: 0.7565212	total: 1.63s	remaining: 28s
# 155:	learn: 0.7562765	total: 1.64s	remaining: 28s
# 156:	learn: 0.7558468	total: 1.65s	remaining: 28s
# 157:	learn: 0.7552681	total: 1.66s	remaining: 28s
# 158:	learn: 0.7549197	total: 1.67s	remaining: 28s
# 159:	learn: 0.7543984	total: 1.68s	remaining: 28s
# 160:	learn: 0.7540885	total: 1.69s	remaining: 28s
# 161:	learn: 0.7538484	total: 1.69s	remaining: 27.8s
# 162:	learn: 0.7535884	total: 1.7s	remaining: 27.8s
# 163:	learn: 0.7533266	total: 1.72s	remaining: 27.8s
# 164:	learn: 0.7529979	total: 1.73s	remaining: 27.8s
# 165:	learn: 0.7526063	total: 1.74s	remaining: 27.8s
# 166:	learn: 0.7521958	total: 1.75s	remaining: 27.8s
# 167:	learn: 0.7517088	total: 1.76s	remaining: 27.8s
# 168:	learn: 0.7514520	total: 1.77s	remaining: 27.8s
# 169:	learn: 0.7512401	total: 1.78s	remaining: 27.8s
# 170:	learn: 0.7508862	total: 1.79s	remaining: 27.8s
# 171:	learn: 0.7505292	total: 1.81s	remaining: 27.9s
# 172:	learn: 0.7502934	total: 1.82s	remaining: 27.9s
# 173:	learn: 0.7499367	total: 1.83s	remaining: 27.9s
# 174:	learn: 0.7497286	total: 1.84s	remaining: 27.9s
# 175:	learn: 0.7494490	total: 1.85s	remaining: 27.9s
# 176:	learn: 0.7492207	total: 1.87s	remaining: 27.9s
# 177:	learn: 0.7489190	total: 1.88s	remaining: 27.9s
# 178:	learn: 0.7484905	total: 1.89s	remaining: 27.9s
# 179:	learn: 0.7481627	total: 1.9s	remaining: 27.9s
# 180:	learn: 0.7477348	total: 1.91s	remaining: 27.9s
# 462:	learn: 0.7104532	total: 4.92s	remaining: 25.1s
# 463:	learn: 0.7103916	total: 4.93s	remaining: 25.1s
# 464:	learn: 0.7103460	total: 4.94s	remaining: 25.1s
# 465:	learn: 0.7102790	total: 4.95s	remaining: 25.1s
# 466:	learn: 0.7101569	total: 4.96s	remaining: 25.1s
# 467:	learn: 0.7100247	total: 4.97s	remaining: 25.1s
# 468:	learn: 0.7099040	total: 4.99s	remaining: 25.1s
# 469:	learn: 0.7098760	total: 5s	remaining: 25s
# 470:	learn: 0.7097863	total: 5.01s	remaining: 25s
# 471:	learn: 0.7097364	total: 5.02s	remaining: 25s
# 472:	learn: 0.7096830	total: 5.03s	remaining: 25s
# 473:	learn: 0.7096257	total: 5.04s	remaining: 25s
# 474:	learn: 0.7095774	total: 5.05s	remaining: 25s
# 475:	learn: 0.7094141	total: 5.06s	remaining: 25s
# 476:	learn: 0.7093099	total: 5.07s	remaining: 25s
# 477:	learn: 0.7092438	total: 5.08s	remaining: 25s
# 478:	learn: 0.7091844	total: 5.09s	remaining: 25s
# 479:	learn: 0.7091379	total: 5.1s	remaining: 24.9s
# 480:	learn: 0.7090765	total: 5.12s	remaining: 25s
# 481:	learn: 0.7089669	total: 5.13s	remaining: 24.9s
# 482:	learn: 0.7089156	total: 5.14s	remaining: 24.9s
# 483:	learn: 0.7088648	total: 5.15s	remaining: 24.9s
# 484:	learn: 0.7087614	total: 5.16s	remaining: 24.9s
# 485:	learn: 0.7086729	total: 5.17s	remaining: 24.9s
# 486:	learn: 0.7086417	total: 5.18s	remaining: 24.9s
# 487:	learn: 0.7086041	total: 5.19s	remaining: 24.9s
# 488:	learn: 0.7085364	total: 5.2s	remaining: 24.9s
# 489:	learn: 0.7084260	total: 5.21s	remaining: 24.9s
# 490:	learn: 0.7083653	total: 5.22s	remaining: 24.8s
# 491:	learn: 0.7082649	total: 5.24s	remaining: 24.8s
# 492:	learn: 0.7081960	total: 5.25s	remaining: 24.8s
# 493:	learn: 0.7081360	total: 5.26s	remaining: 24.8s
# 494:	learn: 0.7080777	total: 5.27s	remaining: 24.8s
# 495:	learn: 0.7080004	total: 5.28s	remaining: 24.8s
# 496:	learn: 0.7079275	total: 5.29s	remaining: 24.8s
# 497:	learn: 0.7078629	total: 5.3s	remaining: 24.8s
# 498:	learn: 0.7077703	total: 5.31s	remaining: 24.8s
# 499:	learn: 0.7077233	total: 5.32s	remaining: 24.8s
# 500:	learn: 0.7076507	total: 5.33s	remaining: 24.7s
# 501:	learn: 0.7076094	total: 5.34s	remaining: 24.7s
# 502:	learn: 0.7075670	total: 5.35s	remaining: 24.7s
# 503:	learn: 0.7075159	total: 5.36s	remaining: 24.7s
# 504:	learn: 0.7074531	total: 5.38s	remaining: 24.7s
# 505:	learn: 0.7073836	total: 5.38s	remaining: 24.7s
# 506:	learn: 0.7072990	total: 5.4s	remaining: 24.7s
# 507:	learn: 0.7072085	total: 5.41s	remaining: 24.7s
# 508:	learn: 0.7071603	total: 5.42s	remaining: 24.7s
# 743:	learn: 0.6929951	total: 7.96s	remaining: 22.3s
# 744:	learn: 0.6929685	total: 7.97s	remaining: 22.3s
# 745:	learn: 0.6929322	total: 7.98s	remaining: 22.3s
# 746:	learn: 0.6928789	total: 7.99s	remaining: 22.2s
# 747:	learn: 0.6928031	total: 8s	remaining: 22.2s
# 748:	learn: 0.6927652	total: 8.01s	remaining: 22.2s
# 749:	learn: 0.6927336	total: 8.02s	remaining: 22.2s
# 750:	learn: 0.6927143	total: 8.03s	remaining: 22.2s
# 751:	learn: 0.6926267	total: 8.04s	remaining: 22.2s
# 752:	learn: 0.6926118	total: 8.05s	remaining: 22.2s
# 753:	learn: 0.6925865	total: 8.06s	remaining: 22.2s
# 754:	learn: 0.6924692	total: 8.08s	remaining: 22.2s
# 755:	learn: 0.6923687	total: 8.09s	remaining: 22.1s
# 756:	learn: 0.6923475	total: 8.1s	remaining: 22.1s
# 757:	learn: 0.6923239	total: 8.11s	remaining: 22.1s
# 758:	learn: 0.6922820	total: 8.12s	remaining: 22.1s
# 759:	learn: 0.6922204	total: 8.13s	remaining: 22.1s
# 760:	learn: 0.6921555	total: 8.14s	remaining: 22.1s
# 761:	learn: 0.6921022	total: 8.15s	remaining: 22.1s
# 762:	learn: 0.6920710	total: 8.16s	remaining: 22.1s
# 763:	learn: 0.6920444	total: 8.17s	remaining: 22.1s
# 764:	learn: 0.6920067	total: 8.18s	remaining: 22s
# 765:	learn: 0.6919433	total: 8.19s	remaining: 22s
# 766:	learn: 0.6918998	total: 8.2s	remaining: 22s
# 767:	learn: 0.6918727	total: 8.21s	remaining: 22s
# 768:	learn: 0.6918162	total: 8.23s	remaining: 22s
# 769:	learn: 0.6917703	total: 8.24s	remaining: 22s
# 770:	learn: 0.6917352	total: 8.25s	remaining: 22s
# 771:	learn: 0.6917065	total: 8.26s	remaining: 22s
# 772:	learn: 0.6916430	total: 8.27s	remaining: 22s
# 773:	learn: 0.6916023	total: 8.28s	remaining: 22s
# 774:	learn: 0.6915539	total: 8.29s	remaining: 21.9s
# 775:	learn: 0.6914768	total: 8.3s	remaining: 21.9s
# 776:	learn: 0.6914440	total: 8.31s	remaining: 21.9s
# 777:	learn: 0.6914028	total: 8.32s	remaining: 21.9s
# 778:	learn: 0.6913725	total: 8.33s	remaining: 21.9s
# 779:	learn: 0.6913502	total: 8.35s	remaining: 21.9s
# 780:	learn: 0.6912775	total: 8.36s	remaining: 21.9s
# 781:	learn: 0.6912175	total: 8.37s	remaining: 21.9s
# 782:	learn: 0.6911966	total: 8.38s	remaining: 21.9s
# 783:	learn: 0.6911699	total: 8.39s	remaining: 21.8s
# 784:	learn: 0.6911440	total: 8.4s	remaining: 21.8s
# 785:	learn: 0.6911207	total: 8.41s	remaining: 21.8s
# 786:	learn: 0.6910874	total: 8.42s	remaining: 21.8s
# 787:	learn: 0.6910457	total: 8.43s	remaining: 21.8s
# 788:	learn: 0.6909961	total: 8.44s	remaining: 21.8s
# 789:	learn: 0.6909582	total: 8.45s	remaining: 21.8s
# 790:	learn: 0.6909291	total: 8.46s	remaining: 21.8s
# 791:	learn: 0.6908591	total: 8.47s	remaining: 21.8s
# 792:	learn: 0.6908249	total: 8.48s	remaining: 21.8s
# 793:	learn: 0.6907934	total: 8.49s	remaining: 21.7s
# 794:	learn: 0.6907584	total: 8.51s	remaining: 21.7s
# 795:	learn: 0.6907268	total: 8.52s	remaining: 21.7s
# 796:	learn: 0.6907123	total: 8.53s	remaining: 21.7s
# 797:	learn: 0.6906764	total: 8.54s	remaining: 21.7s
# 798:	learn: 0.6906546	total: 8.55s	remaining: 21.7s
# 799:	learn: 0.6906134	total: 8.57s	remaining: 21.7s
# 800:	learn: 0.6905662	total: 8.58s	remaining: 21.7s
# 801:	learn: 0.6905332	total: 8.59s	remaining: 21.7s
# 802:	learn: 0.6904697	total: 8.6s	remaining: 21.7s
# 803:	learn: 0.6904302	total: 8.61s	remaining: 21.7s
# 804:	learn: 0.6904048	total: 8.62s	remaining: 21.6s
# 805:	learn: 0.6903530	total: 8.63s	remaining: 21.6s
# 806:	learn: 0.6902830	total: 8.64s	remaining: 21.6s
# 807:	learn: 0.6902632	total: 8.65s	remaining: 21.6s
# 808:	learn: 0.6902033	total: 8.66s	remaining: 21.6s
# 809:	learn: 0.6901460	total: 8.68s	remaining: 21.6s
# 810:	learn: 0.6900807	total: 8.69s	remaining: 21.6s
# 811:	learn: 0.6900489	total: 8.7s	remaining: 21.6s
# 812:	learn: 0.6900327	total: 8.71s	remaining: 21.6s
# 813:	learn: 0.6900164	total: 8.72s	remaining: 21.6s
# 814:	learn: 0.6899608	total: 8.73s	remaining: 21.5s
# 815:	learn: 0.6899217	total: 8.74s	remaining: 21.5s
# 816:	learn: 0.6898844	total: 8.75s	remaining: 21.5s
# 817:	learn: 0.6898151	total: 8.76s	remaining: 21.5s
# 818:	learn: 0.6897929	total: 8.77s	remaining: 21.5s
# 819:	learn: 0.6897715	total: 8.79s	remaining: 21.5s
# 820:	learn: 0.6897432	total: 8.79s	remaining: 21.5s
# 821:	learn: 0.6897212	total: 8.8s	remaining: 21.5s
# 822:	learn: 0.6896441	total: 8.82s	remaining: 21.5s
# 823:	learn: 0.6896302	total: 8.83s	remaining: 21.4s
# 824:	learn: 0.6896158	total: 8.84s	remaining: 21.4s
# 825:	learn: 0.6895891	total: 8.85s	remaining: 21.4s
# 826:	learn: 0.6895027	total: 8.86s	remaining: 21.4s
# 827:	learn: 0.6894842	total: 8.87s	remaining: 21.4s
# 828:	learn: 0.6894672	total: 8.88s	remaining: 21.4s
# 829:	learn: 0.6894316	total: 8.89s	remaining: 21.4s
# 830:	learn: 0.6893737	total: 8.9s	remaining: 21.4s
# 831:	learn: 0.6893337	total: 8.91s	remaining: 21.4s
# 832:	learn: 0.6892775	total: 8.92s	remaining: 21.3s
# 833:	learn: 0.6892431	total: 8.93s	remaining: 21.3s
# 834:	learn: 0.6892210	total: 8.95s	remaining: 21.3s
# 835:	learn: 0.6891981	total: 8.96s	remaining: 21.3s
# 836:	learn: 0.6891557	total: 8.97s	remaining: 21.3s
# 837:	learn: 0.6891255	total: 8.98s	remaining: 21.3s
# 838:	learn: 0.6890732	total: 8.99s	remaining: 21.3s
# 839:	learn: 0.6890637	total: 9s	remaining: 21.3s
# 840:	learn: 0.6890393	total: 9.01s	remaining: 21.3s
# 841:	learn: 0.6890247	total: 9.02s	remaining: 21.3s
# 842:	learn: 0.6889778	total: 9.03s	remaining: 21.2s
# 843:	learn: 0.6888893	total: 9.04s	remaining: 21.2s
# 844:	learn: 0.6888344	total: 9.05s	remaining: 21.2s
# 845:	learn: 0.6888171	total: 9.06s	remaining: 21.2s
# 846:	learn: 0.6887948	total: 9.07s	remaining: 21.2s
# 847:	learn: 0.6887784	total: 9.08s	remaining: 21.2s
# 848:	learn: 0.6887338	total: 9.1s	remaining: 21.2s
# 849:	learn: 0.6887122	total: 9.11s	remaining: 21.2s
# 850:	learn: 0.6886830	total: 9.12s	remaining: 21.2s
# 851:	learn: 0.6886447	total: 9.13s	remaining: 21.1s
# 852:	learn: 0.6886303	total: 9.14s	remaining: 21.1s
# 853:	learn: 0.6886099	total: 9.15s	remaining: 21.1s
# 854:	learn: 0.6885797	total: 9.16s	remaining: 21.1s
# 855:	learn: 0.6885264	total: 9.17s	remaining: 21.1s
# 856:	learn: 0.6885089	total: 9.18s	remaining: 21.1s
# 857:	learn: 0.6884827	total: 9.2s	remaining: 21.1s
# 858:	learn: 0.6884200	total: 9.21s	remaining: 21.1s
# 859:	learn: 0.6883906	total: 9.22s	remaining: 21.1s
# 860:	learn: 0.6883606	total: 9.23s	remaining: 21.1s
# 861:	learn: 0.6883304	total: 9.24s	remaining: 21s
# 862:	learn: 0.6883123	total: 9.25s	remaining: 21s
# 863:	learn: 0.6882466	total: 9.26s	remaining: 21s
# 864:	learn: 0.6882295	total: 9.27s	remaining: 21s
# 865:	learn: 0.6882050	total: 9.28s	remaining: 21s
# 866:	learn: 0.6881043	total: 9.29s	remaining: 21s
# 867:	learn: 0.6880229	total: 9.3s	remaining: 21s
# 868:	learn: 0.6879987	total: 9.31s	remaining: 21s
# 869:	learn: 0.6879787	total: 9.32s	remaining: 21s
# 870:	learn: 0.6879246	total: 9.33s	remaining: 20.9s
# 871:	learn: 0.6878896	total: 9.34s	remaining: 20.9s
# 872:	learn: 0.6878506	total: 9.36s	remaining: 20.9s
# 873:	learn: 0.6878264	total: 9.37s	remaining: 20.9s
# 874:	learn: 0.6877991	total: 9.38s	remaining: 20.9s
# 875:	learn: 0.6877698	total: 9.39s	remaining: 20.9s
# 876:	learn: 0.6877362	total: 9.4s	remaining: 20.9s
# 877:	learn: 0.6877191	total: 9.41s	remaining: 20.9s
# 878:	learn: 0.6876887	total: 9.42s	remaining: 20.9s
# 879:	learn: 0.6876529	total: 9.43s	remaining: 20.9s
# 880:	learn: 0.6875983	total: 9.44s	remaining: 20.8s
# 881:	learn: 0.6875309	total: 9.45s	remaining: 20.8s
# 882:	learn: 0.6875024	total: 9.46s	remaining: 20.8s
# 883:	learn: 0.6874652	total: 9.47s	remaining: 20.8s
# 2574:	learn: 0.6464567	total: 28.1s	remaining: 2.74s
# 2575:	learn: 0.6464486	total: 28.1s	remaining: 2.73s
# 2576:	learn: 0.6464427	total: 28.1s	remaining: 2.72s
# 2577:	learn: 0.6464183	total: 28.1s	remaining: 2.71s
# 2578:	learn: 0.6464100	total: 28.1s	remaining: 2.69s
# 2579:	learn: 0.6463898	total: 28.1s	remaining: 2.68s
# 2580:	learn: 0.6463839	total: 28.2s	remaining: 2.67s
# 2581:	learn: 0.6463558	total: 28.2s	remaining: 2.66s
# 2582:	learn: 0.6463497	total: 28.2s	remaining: 2.65s
# 2583:	learn: 0.6463436	total: 28.2s	remaining: 2.64s
# 2584:	learn: 0.6463357	total: 28.2s	remaining: 2.63s
# 2585:	learn: 0.6463247	total: 28.2s	remaining: 2.62s
# 2586:	learn: 0.6463187	total: 28.2s	remaining: 2.61s
# 2587:	learn: 0.6463089	total: 28.2s	remaining: 2.6s
# 2588:	learn: 0.6463046	total: 28.2s	remaining: 2.58s
# 2589:	learn: 0.6463003	total: 28.3s	remaining: 2.57s
# 2590:	learn: 0.6462794	total: 28.3s	remaining: 2.56s
# 2591:	learn: 0.6462553	total: 28.3s	remaining: 2.55s
# 2592:	learn: 0.6462328	total: 28.3s	remaining: 2.54s
# 2593:	learn: 0.6461972	total: 28.3s	remaining: 2.53s
# 2594:	learn: 0.6461853	total: 28.3s	remaining: 2.52s
# 2595:	learn: 0.6461562	total: 28.3s	remaining: 2.51s
# 2596:	learn: 0.6461516	total: 28.3s	remaining: 2.5s
# 2597:	learn: 0.6461407	total: 28.3s	remaining: 2.49s
# 2598:	learn: 0.6461029	total: 28.4s	remaining: 2.48s
# 2599:	learn: 0.6460939	total: 28.4s	remaining: 2.46s
# 2600:	learn: 0.6460898	total: 28.4s	remaining: 2.45s
# 2601:	learn: 0.6460844	total: 28.4s	remaining: 2.44s
# 2602:	learn: 0.6460799	total: 28.4s	remaining: 2.43s
# 2603:	learn: 0.6460723	total: 28.4s	remaining: 2.42s
# 2604:	learn: 0.6460669	total: 28.4s	remaining: 2.41s
# 2605:	learn: 0.6460590	total: 28.4s	remaining: 2.4s
# 2606:	learn: 0.6460541	total: 28.4s	remaining: 2.39s
# 2607:	learn: 0.6460482	total: 28.4s	remaining: 2.38s
# 2608:	learn: 0.6460415	total: 28.5s	remaining: 2.37s
# 2609:	learn: 0.6460341	total: 28.5s	remaining: 2.35s
# 2610:	learn: 0.6460292	total: 28.5s	remaining: 2.35s
# 2611:	learn: 0.6460158	total: 28.5s	remaining: 2.33s
# 2612:	learn: 0.6459706	total: 28.5s	remaining: 2.32s
# 2613:	learn: 0.6459668	total: 28.5s	remaining: 2.31s
# 2614:	learn: 0.6459140	total: 28.5s	remaining: 2.3s
# 2615:	learn: 0.6458480	total: 28.5s	remaining: 2.29s
# 2616:	learn: 0.6458002	total: 28.5s	remaining: 2.28s
# 2617:	learn: 0.6457944	total: 28.6s	remaining: 2.27s
# 2618:	learn: 0.6457889	total: 28.6s	remaining: 2.26s
# 2619:	learn: 0.6457708	total: 28.6s	remaining: 2.25s
# 2620:	learn: 0.6457378	total: 28.6s	remaining: 2.24s
# 2621:	learn: 0.6457340	total: 28.6s	remaining: 2.23s
# 2622:	learn: 0.6457301	total: 28.6s	remaining: 2.21s
# 2623:	learn: 0.6457230	total: 28.6s	remaining: 2.2s
# 2624:	learn: 0.6457116	total: 28.6s	remaining: 2.19s
# 2625:	learn: 0.6457065	total: 28.6s	remaining: 2.18s
# 2626:	learn: 0.6457033	total: 28.7s	remaining: 2.17s
# 2627:	learn: 0.6456961	total: 28.7s	remaining: 2.16s
# 2628:	learn: 0.6456927	total: 28.7s	remaining: 2.15s
# 2629:	learn: 0.6456870	total: 28.7s	remaining: 2.14s
# 2630:	learn: 0.6456818	total: 28.7s	remaining: 2.13s
# 2631:	learn: 0.6456774	total: 28.7s	remaining: 2.12s
# 2632:	learn: 0.6456386	total: 28.7s	remaining: 2.1s
# 2633:	learn: 0.6456324	total: 28.7s	remaining: 2.09s
# 2634:	learn: 0.6456263	total: 28.7s	remaining: 2.08s
# 2635:	learn: 0.6456207	total: 28.8s	remaining: 2.07s
# 2636:	learn: 0.6456168	total: 28.8s	remaining: 2.06s
# 2637:	learn: 0.6456130	total: 28.8s	remaining: 2.05s
# 2638:	learn: 0.6455161	total: 28.8s	remaining: 2.04s
# 2639:	learn: 0.6455118	total: 28.8s	remaining: 2.03s
# 2640:	learn: 0.6455063	total: 28.8s	remaining: 2.02s
# 2641:	learn: 0.6455009	total: 28.8s	remaining: 2.01s
# 2642:	learn: 0.6454957	total: 28.8s	remaining: 2s
# 2643:	learn: 0.6454911	total: 28.8s	remaining: 1.99s
# 2644:	learn: 0.6454865	total: 28.9s	remaining: 1.97s
# 2645:	learn: 0.6454812	total: 28.9s	remaining: 1.96s
# 2646:	learn: 0.6454306	total: 28.9s	remaining: 1.95s
# 2647:	learn: 0.6454254	total: 28.9s	remaining: 1.94s
# 2648:	learn: 0.6454204	total: 28.9s	remaining: 1.93s
# 2649:	learn: 0.6454120	total: 28.9s	remaining: 1.92s
# 2650:	learn: 0.6453851	total: 28.9s	remaining: 1.91s
# 2651:	learn: 0.6453710	total: 28.9s	remaining: 1.9s
# 2652:	learn: 0.6453675	total: 29s	remaining: 1.89s
# 2653:	learn: 0.6453628	total: 29s	remaining: 1.88s
# 2654:	learn: 0.6453580	total: 29s	remaining: 1.87s
# 2655:	learn: 0.6453527	total: 29s	remaining: 1.85s
# 2656:	learn: 0.6453392	total: 29s	remaining: 1.84s
# 2657:	learn: 0.6453331	total: 29s	remaining: 1.83s
# 2658:	learn: 0.6453256	total: 29s	remaining: 1.82s
# 2659:	learn: 0.6453080	total: 29s	remaining: 1.81s
# 2660:	learn: 0.6453019	total: 29s	remaining: 1.8s
# 2661:	learn: 0.6452688	total: 29s	remaining: 1.79s
# 2662:	learn: 0.6452473	total: 29.1s	remaining: 1.78s
# 2663:	learn: 0.6452417	total: 29.1s	remaining: 1.77s
# 2664:	learn: 0.6452359	total: 29.1s	remaining: 1.76s
# 2665:	learn: 0.6452308	total: 29.1s	remaining: 1.75s
# 2666:	learn: 0.6452255	total: 29.1s	remaining: 1.74s
# 2667:	learn: 0.6452202	total: 29.1s	remaining: 1.72s
# 2668:	learn: 0.6452136	total: 29.1s	remaining: 1.71s
# 2669:	learn: 0.6452084	total: 29.1s	remaining: 1.7s
# 2670:	learn: 0.6452047	total: 29.1s	remaining: 1.69s
# 2671:	learn: 0.6451989	total: 29.2s	remaining: 1.68s
# 2672:	learn: 0.6451914	total: 29.2s	remaining: 1.67s
# 2673:	learn: 0.6451875	total: 29.2s	remaining: 1.66s
# 2674:	learn: 0.6451822	total: 29.2s	remaining: 1.65s
# 2675:	learn: 0.6451682	total: 29.2s	remaining: 1.64s
# 2676:	learn: 0.6451326	total: 29.2s	remaining: 1.63s
# 2677:	learn: 0.6451019	total: 29.2s	remaining: 1.61s
# 2678:	learn: 0.6450863	total: 29.2s	remaining: 1.6s
# 2679:	learn: 0.6450714	total: 29.2s	remaining: 1.59s
# 2680:	learn: 0.6450552	total: 29.3s	remaining: 1.58s
# 2681:	learn: 0.6450481	total: 29.3s	remaining: 1.57s
# 2682:	learn: 0.6450426	total: 29.3s	remaining: 1.56s
# 2683:	learn: 0.6450163	total: 29.3s	remaining: 1.55s
# 2684:	learn: 0.6450101	total: 29.3s	remaining: 1.54s
# 2685:	learn: 0.6449987	total: 29.3s	remaining: 1.53s
# 2686:	learn: 0.6449601	total: 29.3s	remaining: 1.52s
# 2687:	learn: 0.6449542	total: 29.3s	remaining: 1.5s
# 2688:	learn: 0.6449493	total: 29.3s	remaining: 1.49s
# 2689:	learn: 0.6449452	total: 29.4s	remaining: 1.48s
# 2690:	learn: 0.6449394	total: 29.4s	remaining: 1.47s
# 2691:	learn: 0.6449340	total: 29.4s	remaining: 1.46s
# 2692:	learn: 0.6449288	total: 29.4s	remaining: 1.45s
# 2693:	learn: 0.6449061	total: 29.4s	remaining: 1.44s
# 2694:	learn: 0.6449000	total: 29.4s	remaining: 1.43s
# 2695:	learn: 0.6448943	total: 29.4s	remaining: 1.42s
# 2696:	learn: 0.6448900	total: 29.4s	remaining: 1.41s
# 2697:	learn: 0.6448762	total: 29.4s	remaining: 1.4s
# 2698:	learn: 0.6447810	total: 29.4s	remaining: 1.39s
# 2699:	learn: 0.6447766	total: 29.5s	remaining: 1.37s
# 2700:	learn: 0.6447717	total: 29.5s	remaining: 1.36s
# 2701:	learn: 0.6447248	total: 29.5s	remaining: 1.35s
# 2702:	learn: 0.6447197	total: 29.5s	remaining: 1.34s
# 2703:	learn: 0.6447139	total: 29.5s	remaining: 1.33s
# 2704:	learn: 0.6447075	total: 29.5s	remaining: 1.32s
# 2705:	learn: 0.6447030	total: 29.5s	remaining: 1.31s
# 2706:	learn: 0.6446960	total: 29.5s	remaining: 1.3s
# 2707:	learn: 0.6446879	total: 29.5s	remaining: 1.29s
# 2708:	learn: 0.6446820	total: 29.6s	remaining: 1.28s
# 2709:	learn: 0.6446762	total: 29.6s	remaining: 1.26s
# 2710:	learn: 0.6446705	total: 29.6s	remaining: 1.25s
# 2711:	learn: 0.6446670	total: 29.6s	remaining: 1.24s
# 2712:	learn: 0.6446185	total: 29.6s	remaining: 1.23s
# 2713:	learn: 0.6446131	total: 29.6s	remaining: 1.22s
# 2714:	learn: 0.6446066	total: 29.6s	remaining: 1.21s
# 2715:	learn: 0.6445914	total: 29.6s	remaining: 1.2s
# 2716:	learn: 0.6445824	total: 29.6s	remaining: 1.19s
# 2717:	learn: 0.6445785	total: 29.7s	remaining: 1.18s
# 2718:	learn: 0.6445504	total: 29.7s	remaining: 1.17s
# 2719:	learn: 0.6445337	total: 29.7s	remaining: 1.16s
# 2720:	learn: 0.6445285	total: 29.7s	remaining: 1.15s
# 2721:	learn: 0.6444897	total: 29.7s	remaining: 1.13s
# 2722:	learn: 0.6444846	total: 29.7s	remaining: 1.12s
# 2723:	learn: 0.6444609	total: 29.7s	remaining: 1.11s
# 2724:	learn: 0.6444567	total: 29.7s	remaining: 1.1s
# 2725:	learn: 0.6444076	total: 29.7s	remaining: 1.09s
# 2726:	learn: 0.6444024	total: 29.7s	remaining: 1.08s
# 2727:	learn: 0.6443970	total: 29.8s	remaining: 1.07s
# 2728:	learn: 0.6443869	total: 29.8s	remaining: 1.06s
# 2729:	learn: 0.6443811	total: 29.8s	remaining: 1.05s
# 2730:	learn: 0.6443719	total: 29.8s	remaining: 1.04s
# 2731:	learn: 0.6443656	total: 29.8s	remaining: 1.02s
# 2732:	learn: 0.6443597	total: 29.8s	remaining: 1.01s
# 2733:	learn: 0.6443541	total: 29.8s	remaining: 1s
# 2734:	learn: 0.6443505	total: 29.8s	remaining: 992ms
# 2735:	learn: 0.6443457	total: 29.8s	remaining: 982ms
# 2736:	learn: 0.6443099	total: 29.8s	remaining: 971ms
# 2737:	learn: 0.6442325	total: 29.9s	remaining: 960ms
# 2738:	learn: 0.6442277	total: 29.9s	remaining: 949ms
# 2739:	learn: 0.6442220	total: 29.9s	remaining: 938ms
# 2740:	learn: 0.6442170	total: 29.9s	remaining: 927ms
# 2741:	learn: 0.6441731	total: 29.9s	remaining: 916ms
# 2742:	learn: 0.6441679	total: 29.9s	remaining: 905ms
# 2743:	learn: 0.6441639	total: 29.9s	remaining: 894ms
# 2744:	learn: 0.6441596	total: 29.9s	remaining: 883ms
# 2745:	learn: 0.6441543	total: 29.9s	remaining: 872ms
# 2746:	learn: 0.6441483	total: 30s	remaining: 861ms
# 2747:	learn: 0.6441429	total: 30s	remaining: 851ms
# 2748:	learn: 0.6441305	total: 30s	remaining: 840ms
# 2749:	learn: 0.6441202	total: 30s	remaining: 829ms
# 2750:	learn: 0.6440974	total: 30s	remaining: 818ms
# 2751:	learn: 0.6440929	total: 30s	remaining: 808ms
# 2752:	learn: 0.6440874	total: 30s	remaining: 797ms
# 2753:	learn: 0.6440347	total: 30.1s	remaining: 786ms
# 2754:	learn: 0.6440274	total: 30.1s	remaining: 775ms
# 2755:	learn: 0.6439627	total: 30.1s	remaining: 764ms
# 2756:	learn: 0.6439584	total: 30.1s	remaining: 753ms
# 2804:	learn: 0.6430586	total: 30.6s	remaining: 229ms
# 2805:	learn: 0.6430538	total: 30.6s	remaining: 218ms
# 2806:	learn: 0.6430497	total: 30.6s	remaining: 207ms
# 2807:	learn: 0.6430474	total: 30.6s	remaining: 196ms
# 2808:	learn: 0.6430398	total: 30.6s	remaining: 185ms
# 2809:	learn: 0.6430360	total: 30.6s	remaining: 175ms
# 2810:	learn: 0.6430306	total: 30.7s	remaining: 164ms
# 2811:	learn: 0.6430255	total: 30.7s	remaining: 153ms
# 2812:	learn: 0.6430219	total: 30.7s	remaining: 142ms
# 2813:	learn: 0.6430170	total: 30.7s	remaining: 131ms
# 2814:	learn: 0.6430087	total: 30.7s	remaining: 120ms
# 2815:	learn: 0.6430033	total: 30.7s	remaining: 109ms
# 2816:	learn: 0.6429600	total: 30.7s	remaining: 98.2ms
# 2817:	learn: 0.6428063	total: 30.7s	remaining: 87.3ms
# 2818:	learn: 0.6427190	total: 30.7s	remaining: 76.3ms
# 2819:	learn: 0.6426673	total: 30.8s	remaining: 65.4ms
# 2820:	learn: 0.6426359	total: 30.8s	remaining: 54.5ms
# 2821:	learn: 0.6425915	total: 30.8s	remaining: 43.6ms
# 2822:	learn: 0.6425885	total: 30.8s	remaining: 32.7ms
# 2823:	learn: 0.6425854	total: 30.8s	remaining: 21.8ms
# 2824:	learn: 0.6425800	total: 30.8s	remaining: 10.9ms
# 2825:	learn: 0.6425754	total: 30.8s	remaining: 0us
# /usr/lib/python3/dist-packages/sklearn/compose/_column_transformer.py:437: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   warnings.warn("Given feature/column names or counts do not match "

# %%
all_data = pd.read_csv("all_with_stores_pop.csv")
all_data.set_index(["dataset", "range_index"], inplace=True)
all_data['in_mall'] = all_data['mall_name'].notna()
all_data['in_chain'] = all_data['chain_name'].notna()
all_data['mall_name'] = all_data['mall_name'].fillna("None")
all_data['as'] = all_data['store_name'].str.contains(r"\b(AS)\b", case=False, regex=True)
all_data['chain_name'] = all_data['chain_name'].fillna("None")
all_data['busstop_id'] = all_data['busstop_id'].map(str)
all_data['lv1'] = all_data['lv1'].map(str)
all_data['lv2'] = all_data['lv2'].map(str)
all_data['lv3'] = all_data['lv3'].map(str)
all_data['lv4'] = all_data['lv4'].map(str)
all_data.drop(columns=[
    'store_name', 
    'address', 
    'mall_name', 
    'busstop_id', 
    'buss_stops_1000', 
    'municipality_name', 
    'lv1', 
    'lv2', 
    'lv3', 
    'lat', 
    'couple_children_0_to_5_years', 
    'couple_without_children_x', 
    'single_parent_children_0_to_5_years', 
    'single_parent_children_18_or_above', 
    'singles_y', 
    'couple_without_children_y', 
    'other_households', 
    'single_parent_with_children', 
    'side_placement', 
    'district_age_35-64_distribution', 
    'municipality_density', 
    'lv2_population_district_div_count_stores', 
    'lv2_population_municipality_div_count_stores', 
    'in_mall', 
    'lv3_population_district_div_count_stores', 
    'municipality_population', 
    'district_population', 
    'municipality_area', 
    'district_name', 
    'num_of_buss_stops_closer_that_1000_to_busstop', 
    'municipality_age_0-14_distribution', 
    'municipality_age_15-34_distribution', 
    'municipality_age_35-64_distribution', 
    'municipality_age_65-90_distribution', 
    ], inplace=True)

data_with_label = all_data.loc[["train"]]
data_with_label = data_with_label[data_with_label.revenue != 0]

data_with_label.set_index('store_id', inplace=True)
data_without_label = all_data.loc[['test']]
data_without_label.set_index('store_id', inplace=True)
data_without_label.drop(columns=["revenue"], inplace=True)

X, y = data_with_label.loc[:, data_with_label.columns != 'revenue'], data_with_label['revenue']
y_scaled = np.log1p(y)


X_train = X
y_train = y
y_train_scaled = y_scaled
X_test = data_without_label
# Out:
# /tmp/ipykernel_1832961/3812509102.py:6: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   all_data['as'] = all_data['store_name'].str.contains(r"\b(AS)\b", case=False, regex=True)

# %%
from category_encoders.target_encoder import TargetEncoder
from category_encoders.cat_boost import CatBoostEncoder
numeric_features = X_train.select_dtypes(include=[np.number]).columns
numeric_features = list(numeric_features.to_numpy())

print(numeric_features)

numeric_transformer = Pipeline(
    steps=[
        ("imputer", SimpleImputer(strategy="median")),
        ("scaler", RobustScaler())]
)

categorical_features = X_train.select_dtypes(include=[np.object0]).columns
categorical_transformer = Pipeline(
    steps=[
        ("imputer", SimpleImputer(fill_value="missing", strategy="constant")),
        ("targetencoder", TargetEncoder())
    ]
)


preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numeric_features),
        ("cat", categorical_transformer, categorical_features),
    ],
    remainder="passthrough",
)

categorical_features_include_bool = list(categorical_features.to_numpy())
categorical_features_include_bool.extend(list(X.select_dtypes(include=[np.bool8]).columns.to_numpy()))
# Out:
# ['grunnkrets_id', 'lon', 'other_stores_1000', 'other_stores_100', 'other_stores_50', 'other_stores_250', 'buss_stops_300', 'distance_closest_busstop', 'grunnkrets_1', 'area_km2', 'couple_children_18_or_above', 'couple_children_6_to_17_years', 'single_parent_children_6_to_17_years', 'singles_x', 'all_households', 'couple_with_children', 'district_age_0-14_distribution', 'district_age_15-34_distribution', 'district_age_65-90_distribution', 'grunnkrets_population', 'district_area', 'district_density', 'lv1_population_district_div_count_stores', 'lv4_population_district_div_count_stores', 'lv1_population_municipality_div_count_stores', 'lv3_population_municipality_div_count_stores', 'lv4_population_municipality_div_count_stores']
# /lhome/haaknes/.local/lib/python3.10/site-packages/category_encoders/target_encoder.py:122: FutureWarning: Default parameter min_samples_leaf will change in version 2.6.See https://github.com/scikit-learn-contrib/category_encoders/issues/327
#   warnings.warn("Default parameter min_samples_leaf will change in version 2.6."
# /lhome/haaknes/.local/lib/python3.10/site-packages/category_encoders/target_encoder.py:127: FutureWarning: Default parameter smoothing will change in version 2.6.See https://github.com/scikit-learn-contrib/category_encoders/issues/327
#   warnings.warn("Default parameter smoothing will change in version 2.6."

# %%
params = {'objective': 'fair', 'n_estimators': 1053, 'learning_rate': 0.003027727155477576, 'num_leaves': 74, 'max_depth': 28, 'reg_alpha': 8.10705206591596e-05, 'reg_lambda': 7.02195564769408e-07, 'min_split_gain': 0.22843474074171344, 'colsample_bytree': 0.6342675585544213, 'subsample': 0.7773820418099089, 'subsample_freq': 5, 'min_child_samples': 52, 'deterministic': True}
lgb_pipe = Pipeline(
        steps=[
                # ('columnDropper', columnDropperTransformer(columns)),
                ('preprocessor', preprocessor), 
                # ('select', SelectPercentile(score_func=f_regression, **select_params)),
                ('lgb', 
                # lgb.LGBMRegressor(**{'objective': 'huber', 'metric': 'rmse', 'n_estimators': 1547, 'learning_rate': 0.016204513222864394, 'num_leaves': 31, 'max_depth': 24, 'reg_alpha': 0.005033742884292328, 'reg_lambda': 1.682421479746179e-07, 'min_split_gain': 1.1213815845099397, 'colsample_bytree': 0.5369432156441141, 'subsample': 0.7792673463244961, 'subsample_freq': 1, 'min_child_samples': 7, 'verbose': -1})
                lgb.LGBMRegressor(**params)
                )]
        )
lgb_pipe.fit(X_train, y_train_scaled)
y_lightgbm = lgb_pipe.predict(X_test)
export_to_kaggle_submission(X_test, y_lightgbm, "2022-11-09-lightbgm-target-encoded")
# Out:
# /lhome/haaknes/.local/lib/python3.10/site-packages/category_encoders/target_encoder.py:122: FutureWarning: Default parameter min_samples_leaf will change in version 2.6.See https://github.com/scikit-learn-contrib/category_encoders/issues/327
#   warnings.warn("Default parameter min_samples_leaf will change in version 2.6."
# /lhome/haaknes/.local/lib/python3.10/site-packages/category_encoders/target_encoder.py:127: FutureWarning: Default parameter smoothing will change in version 2.6.See https://github.com/scikit-learn-contrib/category_encoders/issues/327
#   warnings.warn("Default parameter smoothing will change in version 2.6."

# %%
import h2o
from h2o.automl import H2OAutoML
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd


h2o.init()


all_data = pd.read_csv("all_with_stores_pop.csv")
all_data.set_index(["dataset", "range_index"], inplace=True)
all_data['in_mall'] = all_data['mall_name'].notna()
all_data['in_chain'] = all_data['chain_name'].notna()
all_data['mall_name'] = all_data['mall_name'].fillna("None")
all_data['as'] = all_data['store_name'].str.contains(r"\b(AS)\b", case=False, regex=True)
all_data['chain_name'] = all_data['chain_name'].fillna("None")
all_data['busstop_id'] = all_data['busstop_id'].map(str)
all_data['lv1'] = all_data['lv1'].map(str) + "cat"
all_data['lv2'] = all_data['lv2'].map(str) + "cat"
all_data['lv3'] = all_data['lv3'].map(str) + "cat"
all_data['lv4'] = all_data['lv4'].map(str) + "cat"
all_data.drop(columns=[
    'store_name',
    'address',
    'importance_level',
    'busstop_id', 
    'other_stores_50', 
    'buss_stops_300', 
    'municipality_name', 
    'lv1', 
    'lat', 
    'couple_children_6_to_17_years', 
    'couple_without_children_x', 
    'single_parent_children_0_to_5_years', 
    'singles_x', 
    'singles_y', 
    'couple_without_children_y', 
    'couple_with_children', 
    'district_age_0-14_distribution', 
    'district_age_65-90_distribution', 
    'grunnkrets_population', 
    'municipality_density', 
    'all_households', 
    'lv2_population_district_div_count_stores', 
    'lv1_population_municipality_div_count_stores', 
    'lv2_population_municipality_div_count_stores', 
    'in_mall', 
    'lv3_population_district_div_count_stores', 
    'district_name', 
    'num_of_buss_stops_closer_that_1000_to_busstop', 
    'municipality_age_0-14_distribution', 
    'municipality_age_35-64_distribution', 
    'municipality_age_65-90_distribution', 

    ], inplace=True)

data_with_label = all_data.loc[["train"]]
data_with_label = data_with_label[data_with_label.revenue != 0]

data_with_label.set_index('store_id', inplace=True)
data_without_label = all_data.loc[['test']]
data_without_label.set_index('store_id', inplace=True)
data_without_label.drop(columns=["revenue"], inplace=True)

X, y = data_with_label.loc[:, data_with_label.columns != 'revenue'], data_with_label['revenue']

y_log = np.log1p(y)
scaler = RobustScaler().fit(X[numeric_features])
X_scaled = scaler.transform(X[numeric_features])
X_num = pd.DataFrame(X_scaled, columns=numeric_features)
X_num.index = X.index
X_categorical = X[X.select_dtypes(exclude=[np.number]).columns]
X = X_num.merge(X_categorical, right_index=True, left_index=True)

temp = X.merge(y_log, left_index=True, right_index=True)
hf = h2o.H2OFrame(temp)

categorical_features = X.select_dtypes(include=[np.object0]).columns.to_list()


hf[categorical_features] = hf[categorical_features].asfactor()

y = "revenue"
x = hf.columns
x.remove(y)
aml = H2OAutoML(max_models=300, seed=1)
aml.train(x = x, y = y, training_frame=hf)
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 . connected.
# --------------------------  ------------------------------
# H2O_cluster_uptime:         19 mins 50 secs
# H2O_cluster_timezone:       Europe/Oslo
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.38.0.2
# H2O_cluster_version_age:    13 days
# H2O_cluster_name:           H2O_from_python_haaknes_e8fccw
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    7.810 Gb
# H2O_cluster_total_cores:    4
# H2O_cluster_allowed_cores:  4
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.10.6 final
# --------------------------  ------------------------------
# /tmp/ipykernel_1832961/831910145.py:16: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   all_data['as'] = all_data['store_name'].str.contains(r"\b(AS)\b", case=False, regex=True)
#                             grunnkrets_id       lon  other_stores_1000  \
# store_id
# 983540538-974187930-44774       -0.271867 -0.055693           1.519824
# 916139195-998469740-540508      -0.271867 -0.055266           1.550661
# 999512895-999558380-491766      -0.271867 -0.055165           1.541850
# 976377966-976442466-53817       -0.271867 -0.055549           1.458150
# 932212366-971984430-30333       -0.271867 -0.056095           1.414097
# ...                                   ...       ...                ...
# 953779560-972191353-43965        0.183019 -1.307280          -0.048458
# 916925638-917007314-830801      -0.437448  0.173864          -0.352423
# 917494436-917551936-851089       0.861036  2.373721          -0.356828
# 966538279-973502220-35549       -0.093980 -0.228978          -0.370044
# 975807371-975825639-390482      -0.343330 -0.044049          -0.370044
#
#                             other_stores_100  other_stores_250  \
# store_id
# 983540538-974187930-44774           0.814815          1.962963
# 916139195-998469740-540508          0.777778          2.000000
# 999512895-999558380-491766          1.370370          2.000000
# 976377966-976442466-53817           1.037037          2.469136
# 932212366-971984430-30333           0.851852          1.444444
# ...                                      ...               ...
# 953779560-972191353-43965          -0.259259         -0.234568
# 916925638-917007314-830801         -0.259259         -0.296296
# 917494436-917551936-851089         -0.259259         -0.296296
# 966538279-973502220-35549          -0.259259         -0.296296
# 975807371-975825639-390482         -0.259259         -0.296296
#
#                             buss_stops_1000  distance_closest_busstop  \
# store_id
# 983540538-974187930-44774          0.000000                  2.417431
# 916139195-998469740-540508        -0.071429                  1.457241
# 999512895-999558380-491766        -0.071429                  1.538600
# 976377966-976442466-53817         -0.071429                  1.575312
# 932212366-971984430-30333         -0.107143                  1.852382
# ...                                     ...                       ...
# 953779560-972191353-43965          0.392857                 -0.454332
# 916925638-917007314-830801        -0.285714                  0.511161
# 917494436-917551936-851089        -0.035714                 -0.375961
# 966538279-973502220-35549         -0.678571                  1.003754
# 975807371-975825639-390482        -0.464286                  2.235478
#
#                             grunnkrets_1  area_km2  \
# store_id
# 983540538-974187930-44774      -0.271867 -0.273121
# 916139195-998469740-540508     -0.271867 -0.273121
# 999512895-999558380-491766     -0.271867 -0.273121
# 976377966-976442466-53817      -0.271867 -0.273121
# 932212366-971984430-30333      -0.271867 -0.277532
# ...                                  ...       ...
# 953779560-972191353-43965       0.183019  1.455873
# 916925638-917007314-830801     -0.437448  2.057326
# 917494436-917551936-851089      0.861036 -0.202808
# 966538279-973502220-35549      -0.093980  0.616373
# 975807371-975825639-390482     -0.343330  8.033799
#
#                             couple_children_0_to_5_years  ...  \
# store_id                                                  ...
# 983540538-974187930-44774                      -0.406780  ...
# 916139195-998469740-540508                     -0.406780  ...
# 999512895-999558380-491766                     -0.406780  ...
# 976377966-976442466-53817                      -0.406780  ...
# 932212366-971984430-30333                      -0.262712  ...
# ...                                                  ...  ...
# 953779560-972191353-43965                       0.661017  ...
# 916925638-917007314-830801                      0.457627  ...
# 917494436-917551936-851089                      1.584746  ...
# 966538279-973502220-35549                      -0.186441  ...
# 975807371-975825639-390482                     -0.313559  ...
#
#                             lv4_population_municipality_div_count_stores  \
# store_id
# 983540538-974187930-44774                                       3.681393
# 916139195-998469740-540508                                      1.519659
# 999512895-999558380-491766                                      3.681393
# 976377966-976442466-53817                                       0.799082
# 932212366-971984430-30333                                       0.799082
# ...                                                                  ...
# 953779560-972191353-43965                                       4.334844
# 916925638-917007314-830801                                      2.563852
# 917494436-917551936-851089                                     13.214444
# 966538279-973502220-35549                                       9.607646
# 975807371-975825639-390482                                      0.201858
#
#                                          chain_name          mall_name  \
# store_id
# 983540538-974187930-44774                 MCDONALDS  Magasinet Drammen
# 916139195-998469740-540508                     None               None
# 999512895-999558380-491766                 CONSELTO               None
# 976377966-976442466-53817   JONAS B GUNDERSEN NORGE               None
# 932212366-971984430-30333                      None               None
# ...                                             ...                ...
# 953779560-972191353-43965               KONDOMERIET               None
# 916925638-917007314-830801                     None               None
# 917494436-917551936-851089                     None               None
# 966538279-973502220-35549                      None               None
# 975807371-975825639-390482                     None               None
#
#                                lv2        lv3          lv4  \
# store_id
# 983540538-974187930-44774   1.1cat   1.1.1cat   1.1.1.0cat
# 916139195-998469740-540508  1.1cat   1.1.2cat   1.1.2.0cat
# 999512895-999558380-491766  1.1cat   1.1.3cat   1.1.3.0cat
# 976377966-976442466-53817   1.1cat   1.1.5cat   1.1.5.0cat
# 932212366-971984430-30333   1.1cat   1.1.5cat   1.1.5.0cat
# ...                            ...        ...          ...
# 953779560-972191353-43965   2.7cat   2.7.4cat   2.7.4.0cat
# 916925638-917007314-830801  2.8cat  2.8.11cat  2.8.11.2cat
# 917494436-917551936-851089  2.8cat  2.8.11cat  2.8.11.2cat
# 966538279-973502220-35549   2.6cat   2.6.3cat   2.6.3.3cat
# 975807371-975825639-390482  3.3cat   3.3.2cat   3.3.2.0cat
#
#                                 stopplace_type  side_placement  in_chain  \
# store_id
# 983540538-974187930-44774            Kantstopp           RIGHT      True
# 916139195-998469740-540508           Kantstopp           RIGHT     False
# 999512895-999558380-491766           Kantstopp           RIGHT      True
# 976377966-976442466-53817            Kantstopp           RIGHT      True
# 932212366-971984430-30333            Kantstopp           RIGHT     False
# ...                                        ...             ...       ...
# 953779560-972191353-43965                  NaN             NaN      True
# 916925638-917007314-830801  Plattform og lomme           RIGHT     False
# 917494436-917551936-851089                 NaN           RIGHT     False
# 966538279-973502220-35549                  NaN            LEFT     False
# 975807371-975825639-390482                 NaN           RIGHT     False
#
#                                as
# store_id
# 983540538-974187930-44774   False
# 916139195-998469740-540508  False
# 999512895-999558380-491766  False
# 976377966-976442466-53817   False
# 932212366-971984430-30333   False
# ...                           ...
# 953779560-972191353-43965   False
# 916925638-917007314-830801   True
# 917494436-917551936-851089   True
# 966538279-973502220-35549    True
# 975807371-975825639-390482   True
#
# [12612 rows x 36 columns]
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |███████████████████████████████████████████████████████████████| (done) 100%
# Model Details
# =============
# H2OStackedEnsembleEstimator : Stacked Ensemble
# Model Key: StackedEnsemble_AllModels_1_AutoML_4_20221110_130410
#
# No summary for this model
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on train data. **
#
# MSE: 0.3083052052064946
# RMSE: 0.5552523797396051
# MAE: 0.4175769440051165
# RMSLE: 0.24481599476368215
# Mean Residual Deviance: 0.3083052052064946
# R^2: 0.6966211649056242
# Null degrees of freedom: 10051
# Residual degrees of freedom: 10001
# Null deviance: 10215.246265296115
# Residual deviance: 3099.0839227356837
# AIC: 16802.503081827464
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on cross-validation data. **
#
# MSE: 0.46129998850598564
# RMSE: 0.6791906864099254
# MAE: 0.5161985656758667
# RMSLE: 0.2892463811648876
# Mean Residual Deviance: 0.46129998850598564
# R^2: 0.5498879410160514
# Null degrees of freedom: 12611
# Residual degrees of freedom: 12557
# Null deviance: 12927.702241132563
# Residual deviance: 5817.915455037491
# AIC: 26145.316492974474
#
# Cross-Validation Metrics Summary:
#                         mean      sd          cv_1_valid    cv_2_valid    cv_3_valid    cv_4_valid    cv_5_valid
# ----------------------  --------  ----------  ------------  ------------  ------------  ------------  ------------
# mae                     0.516243  0.00874522  0.527315      0.507224      0.522986      0.508858      0.514833
# mean_residual_deviance  0.461292  0.0170406   0.471319      0.446653      0.482243      0.441412      0.464834
# mse                     0.461292  0.0170406   0.471319      0.446653      0.482243      0.441412      0.464834
# null_deviance           2585.54   92.7936     2642.8        2612.77       2633.16       2618.05       2420.92
# r2                      0.549599  0.0182141   0.540751      0.5661        0.53064       0.571882      0.538623
# residual_deviance       1163.64   56.5638     1213.65       1133.6        1235.51       1120.3        1115.14
# rmse                    0.679092  0.012552    0.686527      0.668321      0.694437      0.664389      0.681788
# rmsle                   0.289282  0.00378734  0.292354      0.28586       0.290984      0.284579      0.292632
#
# [tips]
# Use `model.explain()` to inspect the model.
# --
# Use `h2o.display.toggle_user_tips()` to switch on/off this section.

# %%
test = all_data.loc["test"]
test = test.drop(columns="revenue")
X_test_scaled = scaler.transform(test[numeric_features])
test.set_index('store_id', inplace=True)
test_num = pd.DataFrame(X_test_scaled, columns=numeric_features)
test_num.index = test.index
X_test_cat = test[test.select_dtypes(exclude=[np.number]).columns]
test = test_num.merge(X_test_cat, right_index=True, left_index=True)

hf_test = h2o.H2OFrame(test)
hf_test[categorical_features] = hf_test[categorical_features].asfactor()
lb = aml.leaderboard
# Out:
# /tmp/ipykernel_1832961/3426426465.py:6: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   all_data['as'] = all_data['store_name'].str.contains(r"\b(AS)\b", case=False, regex=True)
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
#                             grunnkrets_id        lon  other_stores_1000  \
# store_id
# 884875072-975988988-41051         6020302  10.203772                405
# 999235174-999504078-507807        6020302  10.204229                405
# 916715463-816878292-826266        6020303  10.205869                437
# 999086284-982563895-99598         6020302  10.204229                405
# 979879741-972291455-25435         6020303  10.206751                450
# ...                                   ...        ...                ...
# 917064016-817211402-838350       11491012   5.302505                104
# 917353379-917411824-845904       11030901   5.721546                384
# 917323003-917383529-844309       11490601   5.325813                  0
# 937628668-972044857-47364         3015006  10.638928                 14
# 952390821-971994908-26248         7200102  10.363818                  5
#
#                             other_stores_100  other_stores_250  \
# store_id
# 884875072-975988988-41051                 35               202
# 999235174-999504078-507807                27               206
# 916715463-816878292-826266                31               192
# 999086284-982563895-99598                 27               206
# 979879741-972291455-25435                 95               175
# ...                                      ...               ...
# 917064016-817211402-838350                 0                 0
# 917353379-917411824-845904                 0                 2
# 917323003-917383529-844309                 0                 0
# 937628668-972044857-47364                  0                 1
# 952390821-971994908-26248                  0                 0
#
#                             buss_stops_1000  distance_closest_busstop  \
# store_id
# 884875072-975988988-41051                21                428.072074
# 999235174-999504078-507807               19                375.048455
# 916715463-816878292-826266               19                380.586012
# 999086284-982563895-99598                19                375.048455
# 979879741-972291455-25435                20                494.016863
# ...                                     ...                       ...
# 917064016-817211402-838350               20                 80.760532
# 917353379-917411824-845904               46                160.852730
# 917323003-917383529-844309                9                219.441085
# 937628668-972044857-47364                20                104.456431
# store_id
# 884875072-975988988-41051                                  65.071429
# 999235174-999504078-507807                                 65.071429
# 916715463-816878292-826266                                 65.071429
# 999086284-982563895-99598                                  65.071429
# 979879741-972291455-25435                                  65.071429
# ...                                                              ...
# 917064016-817211402-838350                                115.253333
# 917353379-917411824-845904                                442.800000
# 917323003-917383529-844309                                200.527778
# 937628668-972044857-47364                                1463.500000
# 952390821-971994908-26248                                 555.500000
#
#                             lv4_population_district_div_count_stores  \
# store_id
# 884875072-975988988-41051                                 414.090909
# 999235174-999504078-507807                                414.090909
# 916715463-816878292-826266                                911.000000
# 999086284-982563895-99598                                 759.166667
# 979879741-972291455-25435                                 506.111111
# ...                                                              ...
# 917064016-817211402-838350                               2881.333333
# 917353379-917411824-845904                              17712.000000
# 917323003-917383529-844309                               7219.000000
# 937628668-972044857-47364                                8781.000000
# 952390821-971994908-26248                                2222.000000
#
#                             lv3_population_municipality_div_count_stores  \
# store_id
# 884875072-975988988-41051                                    1252.574074
# 999235174-999504078-507807                                   1252.574074
# 916715463-816878292-826266                                   1252.574074
# 999086284-982563895-99598                                    3381.950000
# 979879741-972291455-25435                                    3381.950000
# ...                                                                  ...
# 917064016-817211402-838350                                  13960.000000
# 917353379-917411824-845904                                  22090.833333
# 917323003-917383529-844309                                  13960.000000
# 937628668-972044857-47364                                    6226.336449
# 952390821-971994908-26248                                    3883.333333
#
#                             lv4_population_municipality_div_count_stores
# store_id
# 884875072-975988988-41051                                    2940.826087
# 999235174-999504078-507807                                   2940.826087
# 916715463-816878292-826266                                   3978.764706
# 999086284-982563895-99598                                    3381.950000
# 979879741-972291455-25435                                    3381.950000
# ...                                                                  ...
# 917064016-817211402-838350                                  13960.000000
# 917353379-917411824-845904                                 132545.000000
# 917323003-917383529-844309                                  41880.000000
# 937628668-972044857-47364                                  333109.000000
# 952390821-971994908-26248                                    5825.000000
#
# [8577 rows x 27 columns]
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%

# %%
for (i, name) in enumerate(lb.head(rows=lb.nrows).as_data_frame()['model_id'][:152]):
    preds = h2o.get_model(name).predict(hf_test)
    preds = preds.as_data_frame()
    preds.index = test.index
    preds.index.name = "id"
    preds.rename(columns={"predict": "predicted"}, inplace=True)
    preds["predicted"] = np.expm1(preds["predicted"])
    preds.to_csv(f"2022-11-10-H2O_300models-scale{i}.csv")

# %%
models = []
cat = pd.read_csv('2022-11-11-catboost-last.csv')
cat.predicted = np.log1p(cat.predicted)

lightbgm = pd.read_csv('2022-11-09-lightbgm-target-encoded.csv')
lightbgm.predicted = np.log1p(lightbgm.predicted)
for i in range(102):
    models.append(pd.read_csv(f"2022-11-10-H2O_300models-scale{i}.csv"))
    models[i].predicted = np.log1p(models[i].predicted)
ensembled = np.expm1(np.sum([cat.predicted*0.12, lightbgm.predicted*0.23, models[0].predicted*0.13, models[1].predicted*0.1, 0.42/5050 *np.sum([(100 - i)* models[i+2].predicted for i in range(100)], axis=0)], axis=0))

cat.predicted = ensembled
cat.to_csv("2022-11-12-cat-012-lgbm_023-model0_013-model1_010-100otherof300_042.csv", index=False)
